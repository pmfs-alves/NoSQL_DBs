# %% [markdown]
# # Big Data Modeling and Management Assigment
#
#
# ## Second Assigment
#
# For this first project we will be taking a european public procurement notices database to analyse contracts and money expenditure within the European Union!
#
# For reference the dataset used for this database has been extracted from [Data Europa](https://data.europa.eu/euodp/en/data/dataset/ted-csv), and the definition of this data can be found [here](https://data.europa.eu/euodp/repository/ec/dg-grow/mapps/2019/TED(csv)_data_information_v3.2.doc).
#
# #### Problem description
#
# Explore the database via python's mongoDB connector and/or the ROBO3T software.
# Answer the questions.
# Submit the results by following the instructions
#
# #### Connection details to the MongoDB database
# Each group should have received by email the credentials to connect to the group's mongo database.
# ```
# Connection example: mongodb://username:password@host:port
# ```
# The database contains 4 collections.
#
#
# ### Questions
#
# #### To use the find Method:
# 1. How many contracts are in the database?
# 1. What is the ('AWARD_VALUE_EURO') of the highest value contract ('AWARD_VALUE_EURO') in the dataset?
# 1. In which years were the first and last contracts celebrated?
# 1. What was the 'CRIT_CRITERIA' of the highest value contract ('AWARD_VALUE_EURO') in Portugal in 2010?
# 1. What was the 'CRIT_CRITERIA' of the highest number of offers ('NUMBER_OFFERS') using European funds?
# 1. Number of contracts that have 'Defence' in the 'MAIN_ACTIVITY' value string?
# 1. Number of contracts where both companies are from the same town?
# 1. Number of contracts where difference between Proposed value ('VALUE_EURO') and awarded value ('AWARD_VALUE_EURO') is greater than 10000000?
#
# #### To use the Aggregate Framework:
# 9. Which country has the most contracts overall?
# 1. Which year had the highest money transactions value ('AWARD_VALUE_EURO')?
#
# ##### Knowing that the cpv division is represented in the first 2 digits of the CPV code ('CPV'):
# 11. Group by year, country and CPV division (this order) and return the average/max and counts of contract award values
#
# ##### Open Question
# 12. Knowing that the dataset has wrongly inserted values, more in particular impossible 'VALUE_EURO' and similar values, how would you deal with this situation?
#
#
#
# ### Group
#
# This project assumes groups to be the same as the previous project, any copying detected by the professors will lead to a grading of zero on the project and/or other disciplinary actions!
#
#
# ### Submission
#
# Each group will have its own database to work with. Use CRUD operations to **create a new collection, called 'results' where you will input your answers**  with the following structure:
#
# - Each answer should be inserted as a document, all documents should have a key 'question' (no caps) were its value is the questions number, and another key called 'answer' where naturally the value should be the answer to that particular question;
#
# - Question 11 output is a list which can also be inserted in the answer value;
#
# - Question 12 should follow the structure of the 'single answer' questions (we expect here a text explaining your strategies to deal with this issue)
#
#
# Example:
# ```
# db["results"].insert_one(
#     {'question' : 0,
#      'answer' : result
#     },
# )
# ```
#
# To evaluate results:
#
# ```
# list(db["results"].find( {'answer' : 0}))
#
# Output: [{'_id': ObjectId('5eb53aa694c09a2299fb069e'), 'question': 0, 'answer': result}]
# ```
#
# Delivery date: Until **23:59 of May 21st**
#
#
# ### Evaluation
#
#
# This will be 15% of the final grade.
# Each solution will be evaluate on 2 components, each equally important: correctness of results and simplicity of the solution.
# All code will go through plagiarism automated checks. Groups with the same code will undergo investigation

# %% [markdown]
# ### Connection to the Database

# %%
from pymongo import MongoClient
import warnings
import credentials as cred
warnings.filterwarnings('ignore')

# %%
host= cred.mongo_host
port= cred.mongo_port
user= cred.mongo_user
password= cred.mongo_pass
protocol="mongodb"
client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# %%
database = client.contracts

col_cpv = database.cpv
col_cpv_codes = database.cpv_codes
col_eu = database.eu
col_iso = database.iso_codes

# %%
col_results = database.results

# %% [markdown]
# ## Queries

# %% [markdown]
# **1.** How many contracts are in the database?

# %%
r1 = col_eu.find().count()
result1 = int(r1)
print(f'There are {result1} contracts in the database.')
# Out:
# There are 5563372 contracts in the database.

# %%
a1 = col_results.insert_one(
    {'question' : 1,
     'answer' : result1
    })

# %% [markdown]
# **2.** What is the ('AWARD_VALUE_EURO') of the highest value contract ('AWARD_VALUE_EURO') in the dataset?

# %%
query =  {'AWARD_VALUE_EURO': {'$exists': True}} 
projection = {'_id': 0, 'AWARD_VALUE_EURO': 1}

r2 = col_eu.find(query, projection).sort('AWARD_VALUE_EURO', -1).limit(1)

result2 = list(r2)
r2 = result2[0].get('AWARD_VALUE_EURO')

print(f'The highest value contract has the value {r2}.')
# Out:
# The highest value contract has the value 1e+20.

# %%
a2 = col_results.insert_one(
    {'question' : 2,
     'answer' : r2
    })

# %% [markdown]
# **Comment**: This values seem to be irrealistic as they are incredible high compared to the highest value contract in Europe and to the european PIB.

# %% [markdown]
# **3.** In which years were the first and last contracts celebrated?

# %%
query =  {} 
projection = {'_id': 0, 'YEAR': 1}

r3_1 = col_eu.find(query, projection).sort('YEAR', 1).limit(1)
r3_2 = col_eu.find(query, projection).sort('YEAR', -1).limit(1)

result3_1 = list(r3_1)
result3_2 = list(r3_2)

r3_1 = result3_1[0].get('YEAR')
r3_2 = result3_2[0].get('YEAR')
r3 = {'First_Year_Contract': r3_1, 'Last_Year_Contract': r3_2}

print(f'The first contract was in {r3_1} and the last contract celebrated in {r3_2}.')
# Out:
# The first contract was in 2009 and the last contract celebrated in 2018.

# %%
a3 = col_results.insert_one(
    {'question' : 3,
     'answer' : r3
    })

# %% [markdown]
# **4.** What was the 'CRIT_CRITERIA' of the highest value contract ('AWARD_VALUE_EURO') in Portugal in 2016?

# %%
query =  {'YEAR': {'$eq': 2016}, 'ISO_COUNTRY_CODE': {'$eq': 'PT'}} 
projection = {'_id': 0, 'CRIT_CRITERIA': 1}

r4 = col_eu.find(query, projection).sort('AWARD_VALUE_EURO', -1).limit(1)

result4 = list(r4)
r4 = result4[0].get('CRIT_CRITERIA')

print(f'The crit_criteria of the highest value contract in Portugal in 2016 was: \n{r4}.')
# Out:
# The crit_criteria of the highest value contract in Portugal in 2016 was:
# Preço por quilómetro percorrido entre o Ponto B e o Ponto C---Percentagem do preço a aplicar à parte do percurso entre o Ponto A — local de saída do prestador — e o Ponto B — local onde se inicia o transporte do doente –, nas deslocações superiores a 20 km---Preço por viagem menor ou igual a 20 km por doente e/ou acompanhante que inclui deslocações de ida e volta («taxa de saída»)---Percentagem do preço a pagar a partir do segundo doente para deslocações superiores a 20 km e inferiores a 100 km, inclusive---Percentagem do preço a pagar a partir do segundo doente para deslocações superiores a 100 km---Percentagem do preço a pagar por cada acompanhante, médico/enfermeiro---Preço máximo a pagar pela segunda hora de espera e subsequentes---Preço do kit de parto---Preço do ventilador---Preço do oxigénio e Capacidade de transporte do concorrente.

# %%
a4 = col_results.insert_one(
    {'question' : 4,
     'answer' : r4
    })

# %% [markdown]
# **5.** What was the 'CRIT_CRITERIA' of the highest number of offers ('NUMBER_OFFERS') using European funds?

# %%
query =  {'B_EU_FUNDS': {'$eq': 'Y'}} 
projection = {'_id': 0, 'CRIT_CRITERIA': 1}

r5 = col_eu.find(query, projection).sort('NUMBER_OFFERS', -1).limit(1)

result5 = list(r5)
r5 = result5[0].get('CRIT_CRITERIA')

print(f'The crit_criteria of the contract with the highest number of offers using European funds was: \n{r5}.')
# Out:
# The crit_criteria of the contract with the highest number of offers using European funds was:
# Cost---Methodology & resources---Understanding of the sensitivities of working on a designated site---Understanding of the difficulties of working on islands.

# %%
a5 = col_results.insert_one(
    {'question' : 5,
     'answer' : r5
    })

# %% [markdown]
# **6.** Number of contracts that have 'Defence' in the 'MAIN_ACTIVITY' value string?

# %%
query =  {'MAIN_ACTIVITY': {'$regex': '.*Defence.*'}}

r6 = col_eu.find(query).count()
result6 = int(r6)

print(f'There are {result6} contracts where the main activity is defence.')
# Out:
# There are 139494 contracts where the main activity is defence.

# %%
# query =  {'MAIN_ACTIVITY': {'$eq': 'Defence'}}

# r6 = col_eu.find(query).count()
# result6 = int(r6)

# print(f'There are {result6} contracts where the main activity is defence.')

# %%
a6 = col_results.insert_one(
    {'question' : 6,
     'answer' : result6
    })

# %% [markdown]
# **7.** Number of contracts where both companies are from the same town?

# %%
query =  {'$expr': {'$eq': ["$CAE_TOWN","$WIN_TOWN"]}}

r7 = col_eu.find(query).count()
result7 = int(r7)

print(f'There are {result7} contracts where both companies are from the same town.')
# Out:
# There are 721751 contracts where both companies are from the same town.

# %%
a7 = col_results.insert_one(
    {'question' : 7,
     'answer' : result7
    })

# %% [markdown]
# **8.** Number of contracts where difference between Proposed value ('VALUE_EURO') and awarded value ('AWARD_VALUE_EURO') is greater than 10000000?

# %%
query =  {'AWARD_VALUE_EURO': {'$exists': True}, 
          'VALUE_EURO': {'$exists': True}, 
         '$expr': {'$gt': [{'$subtract': ["$VALUE_EURO","$AWARD_VALUE_EURO"]}, 10000000]}}

r8 = col_eu.find(query).count()
result8 = int(r8)

print(f'There are {result8} contracts that satisfy the condition.')
# Out:
# There are 110928 contracts that satisfy the condition.

# %%
a8 = col_results.insert_one(
    {'question' : 8,
     'answer' : result8
    })

# %% [markdown]
# **9.** Which country has the most contracts overall?

# %%
query_1 = {
    '$group': {         
        '_id': {'country_code': '$ISO_COUNTRY_CODE'}, 
        'nr_contracts' : {'$sum' : 1}
    }
}
query_2 = {
    '$sort': {'nr_contracts': -1}
}

query_3 = {
    '$limit': 1
}

query_4 = {
    '$lookup': {
            'from': 'iso_codes',
            'localField': '_id.country_code',   
            'foreignField': 'alpha-2',  
            'as': 'COUNTRY'
    }
}

query_5 = {
    '$project': {
        '_id': 0,
        'country': {'$arrayElemAt': ['$COUNTRY.name', 0]}, 
        'nr_contracts': 1
    }
}


pipeline = [query_1, query_2, query_3, query_4, query_5]

r9 = col_eu.aggregate(pipeline)

result9 = list(r9)
c9 = result9[0].get('country')
cont9 = result9[0].get('nr_contracts')
print(f'The country that has the most contracts overall is {c9} with {cont9} contracts.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0029498c630> in <module>
#      33 pipeline = [query_1, query_2, query_3, query_4, query_5]
#      34
# ---> 35 r9 = eu.aggregate(pipeline)
#      36
#      37 # result9 = list(r9)
#
# NameError: name 'eu' is not defined

# %%
a9 = col_results.insert_one(
    {'question' : 9,
     'answer' : c9
    })

# %% [markdown]
# **10.** Which year had the highest money transactions value ('AWARD_VALUE_EURO')?

# %%
query_1 = {
    '$group': {         
        '_id': '$YEAR', 
        'highest_value_transactions' : {'$max' : '$AWARD_VALUE_EURO'} 
    }
}

query_2 = {
    '$sort': {'highest_value_transactions': -1}
}

query_3 = {
    '$limit': 2
}

pipeline = [query_1, query_2, query_3]

r10 = col_eu.aggregate(pipeline)
result10 = list(r10)

c10 = [result10[0].get('_id'), result10[1].get('_id')]
cont10 = result10[0].get('highest_value_transactions')
print(f'The years that have the highest money transaction value are {c10} both with {cont10}.')
# Out:
# The years that have the highest money transaction value are [2013, 2012] both with 1e+20.

# %%
a10 = col_results.insert_one(
    {'question' : 10,
     'answer' : c10
    })

# %% [markdown]
# ##### Knowing that the cpv division is represented in the first 2 digits of the CPV code ('CPV'):

# %% [markdown]
# **11.** Group by year, country and CPV division (this order) and return the average and max and counts of contract award values

# %% [markdown]
# We divided this query into two parts since there was a problem with CPV codes, some of them had only 7 digits because they lost the first zero when converted to integer in the database.
# Therefore, the first part only takes into account the cpv codes with 7 digits and the second part, the cpv codes with 8 digits.

# %%
query_0 = {
    '$match': {
        'AWARD_VALUE_EURO': {'$exists': True},
        'CPV': {'$lt': 10000000}
    }
}

query_1 = {
    '$project': {
        '_id': 0,
        'cpv_division': {'$concat': ['0', "", {'$substr': ['$CPV', 0, 1]}]},
        'award_values': '$AWARD_VALUE_EURO',
        'year': '$YEAR',
        'country_code': '$ISO_COUNTRY_CODE'
    }
}

query_2 = {
    '$group': {
        '_id': {'Year': '$year', 'Country_code': '$country_code', 'CPV_division': '$cpv_division'},
        'Count_award_value': {'$sum': 1},
        'Avg_award_value': {'$avg': '$award_values'},
        'Max_award_value': {'$max': '$award_values'}
    },
}

query_3 = {
    '$lookup': {
            'from': 'iso_codes',
            'localField': '_id.Country_code',   
            'foreignField': 'alpha-2',  
            'as': 'COUNTRY'
    }
}

query_4 = {
    '$project': {
        '_id': 0,
        'Year': '$_id.Year',
        'Country': {'$arrayElemAt': ['$COUNTRY.name', 0]}, 
        'CPV_division': '$_id.CPV_division',
        'Avg_award_value': {'$round': ['$Avg_award_value', 2]},
        'Max_award_value': {'$round': ['$Max_award_value', 2]},
        'Count_award_value': '$Count_award_value' 
    }
}

pipeline = [query_0, query_1, query_2, query_3, query_4]

r11_1 = col_eu.aggregate(pipeline)

result11_1 = list(r11_1)
result11_1
# Out:
# [{'Year': 2009,
#   'Country': 'Switzerland',
#   'CPV_division': '09',
#   'Avg_award_value': 999081.65,
#   'Max_award_value': 3995364.24,
#   'Count_award_value': 4},
#  {'Year': 2013,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 107325.64,
#   'Max_award_value': 333000,
#   'Count_award_value': 8},
#  {'Year': 2010,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 483513.26,
#   'Max_award_value': 1674008.81,
#   'Count_award_value': 12},
#  {'Year': 2015,
#   'Country': 'Iceland',
#   'CPV_division': '09',
#   'Avg_award_value': 2592959.67,
#   'Max_award_value': 2592959.67,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 5684384.94,
#   'Max_award_value': 201859104,
#   'Count_award_value': 340},
#  {'Year': 2016,
#   'Country': 'Sweden',
#   'CPV_division': '03',
#   'Avg_award_value': 11577694.34,
#   'Max_award_value': 33677233.12,
#   'Count_award_value': 8},
#  {'Year': 2012,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 1103286.25,
#   'Max_award_value': 1942010,
#   'Count_award_value': 4},
#  {'Year': 2010,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 1936355.33,
#   'Max_award_value': 22653618.33,
#   'Count_award_value': 56},
#  {'Year': 2016,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 8720467.47,
#   'Max_award_value': 116000000,
#   'Count_award_value': 163},
#  {'Year': 2015,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 2810412.36,
#   'Max_award_value': 4027649.2,
#   'Count_award_value': 8},
#  {'Year': 2013,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 1336771.98,
#   'Max_award_value': 398522930.32,
#   'Count_award_value': 1737},
#  {'Year': 2010,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 875780.25,
#   'Max_award_value': 44920066.79,
#   'Count_award_value': 101},
#  {'Year': 2009,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 162767.96,
#   'Max_award_value': 311899.08,
#   'Count_award_value': 8},
#  {'Year': 2014,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 16772.17,
#   'Max_award_value': 57217.03,
#   'Count_award_value': 11},
#  {'Year': 2015,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 521273.0,
#   'Max_award_value': 616610,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 475961.1,
#   'Max_award_value': 5938186.69,
#   'Count_award_value': 76},
#  {'Year': 2017,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 60367.9,
#   'Max_award_value': 940216,
#   'Count_award_value': 46},
#  {'Year': 2018,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1955353.31,
#   'Max_award_value': 33672480,
#   'Count_award_value': 52},
#  {'Year': 2010,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 263960.99,
#   'Max_award_value': 4034883.17,
#   'Count_award_value': 17},
#  {'Year': 2010,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 18505157.76,
#   'Max_award_value': 3276371460,
#   'Count_award_value': 405},
#  {'Year': 2017,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 42757.33,
#   'Max_award_value': 558924.64,
#   'Count_award_value': 285},
#  {'Year': 2018,
#   'CPV_division': '09',
#   'Avg_award_value': 51633148.78,
#   'Max_award_value': 1720500269.4,
#   'Count_award_value': 178},
#  {'Year': 2014,
#   'Country': 'Switzerland',
#   'CPV_division': '09',
#   'Avg_award_value': 1299101.2,
#   'Max_award_value': 5135642.19,
#   'Count_award_value': 13},
#  {'Year': 2012,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 900963.47,
#   'Max_award_value': 71274905.25,
#   'Count_award_value': 1680},
#  {'Year': 2016,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 2850589.83,
#   'Max_award_value': 85304500,
#   'Count_award_value': 79},
#  {'Year': 2017,
#   'Country': 'Luxembourg',
#   'CPV_division': '03',
#   'Avg_award_value': 389682.73,
#   'Max_award_value': 503891.05,
#   'Count_award_value': 2},
#  {'Year': 2018,
#   'Country': 'Spain',
#   'CPV_division': '03',
#   'Avg_award_value': 42992.31,
#   'Max_award_value': 3597661.4,
#   'Count_award_value': 224},
#  {'Year': 2011,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 581326.17,
#   'Max_award_value': 12106927.65,
#   'Count_award_value': 288},
#  {'Year': 2016,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 429737.76,
#   'Max_award_value': 109756098,
#   'Count_award_value': 487},
#  {'Year': 2017,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 3417928.58,
#   'Max_award_value': 200000000,
#   'Count_award_value': 107},
#  {'Year': 2009,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 2857332.5,
#   'Max_award_value': 6321550,
#   'Count_award_value': 4},
#  {'Year': 2015,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 211604.71,
#   'Max_award_value': 487250,
#   'Count_award_value': 7},
#  {'Year': 2016,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 271280.76,
#   'Max_award_value': 22183720,
#   'Count_award_value': 448},
#  {'Year': 2009,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 496107.38,
#   'Max_award_value': 1294592,
#   'Count_award_value': 5},
#  {'Year': 2011,
#   'Country': 'Switzerland',
#   'CPV_division': '03',
#   'Avg_award_value': 577979.56,
#   'Max_award_value': 577979.56,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 1247290.48,
#   'Max_award_value': 28337800,
#   'Count_award_value': 97},
#  {'Year': 2009,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 228517.07,
#   'Max_award_value': 623362.32,
#   'Count_award_value': 16},
#  {'Year': 2014,
#   'CPV_division': '09',
#   'Avg_award_value': 4849487.3,
#   'Max_award_value': 55822954.4,
#   'Count_award_value': 28},
#  {'Year': 2018,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 11567402.98,
#   'Max_award_value': 1603463536.04,
#   'Count_award_value': 542},
#  {'Year': 2016,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 721736.36,
#   'Max_award_value': 4493090,
#   'Count_award_value': 22},
#  {'Year': 2014,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 439632.91,
#   'Max_award_value': 439632.91,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 110515.05,
#   'Max_award_value': 160000,
#   'Count_award_value': 5},
#  {'Year': 2010,
#   'CPV_division': '03',
#   'Avg_award_value': 570373.33,
#   'Max_award_value': 6994311.29,
#   'Count_award_value': 50},
#  {'Year': 2012,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 200996.0,
#   'Max_award_value': 439764.91,
#   'Count_award_value': 3},
#  {'Year': 2012,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 3944485.28,
#   'Max_award_value': 48000000,
#   'Count_award_value': 21},
#  {'Year': 2016,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 106593.89,
#   'Max_award_value': 946268.4,
#   'Count_award_value': 37},
#  {'Year': 2012,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 535541.27,
#   'Max_award_value': 1663669,
#   'Count_award_value': 9},
#  {'Year': 2013,
#   'Country': 'Switzerland',
#   'CPV_division': '09',
#   'Avg_award_value': 176671.59,
#   'Max_award_value': 1981699.29,
#   'Count_award_value': 34},
#  {'Year': 2018,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1593635.02,
#   'Max_award_value': 464902529,
#   'Count_award_value': 1054},
#  {'Year': 2009,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 4076594.4,
#   'Max_award_value': 29415656.31,
#   'Count_award_value': 18},
#  {'Year': 2014,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 4369310.55,
#   'Max_award_value': 12065000,
#   'Count_award_value': 3},
#  {'Year': 2017,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 228136.47,
#   'Max_award_value': 688868.32,
#   'Count_award_value': 11},
#  {'Year': 2014,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 3959686.93,
#   'Max_award_value': 95000000,
#   'Count_award_value': 148},
#  {'Year': 2010,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 45850.12,
#   'Max_award_value': 209178.89,
#   'Count_award_value': 36},
#  {'Year': 2014,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 2061666.97,
#   'Max_award_value': 117199630.94,
#   'Count_award_value': 302},
#  {'Year': 2012,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 89596.68,
#   'Max_award_value': 136800,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 2533176.5,
#   'Max_award_value': 3996564.5,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 2151719.28,
#   'Max_award_value': 98168686.75,
#   'Count_award_value': 251},
#  {'Year': 2009,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 365342.73,
#   'Max_award_value': 5146436.24,
#   'Count_award_value': 24},
#  {'Year': 2015,
#   'Country': 'Slovenia',
#   'CPV_division': '03',
#   'Avg_award_value': 308791.36,
#   'Max_award_value': 2640000,
#   'Count_award_value': 23},
#  {'Year': 2009,
#   'Country': 'France',
#   'CPV_division': '09',
#   'Avg_award_value': 937813.84,
#   'Max_award_value': 73541296,
#   'Count_award_value': 461},
#  {'Year': 2012,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1123317.09,
#   'Max_award_value': 4152542.37,
#   'Count_award_value': 11},
#  {'Year': 2017,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 1066229.79,
#   'Max_award_value': 167890834.94,
#   'Count_award_value': 1632},
#  {'Year': 2013,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 3723302.39,
#   'Max_award_value': 41817600,
#   'Count_award_value': 165},
#  {'Year': 2010,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 1485395.94,
#   'Max_award_value': 2411583.99,
#   'Count_award_value': 3},
#  {'Year': 2016,
#   'Country': 'Croatia',
#   'CPV_division': '03',
#   'Avg_award_value': 299681.93,
#   'Max_award_value': 3644745.66,
#   'Count_award_value': 41},
#  {'Year': 2012,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 4780261.42,
#   'Max_award_value': 67660000,
#   'Count_award_value': 16},
#  {'Year': 2015,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 147734.96,
#   'Max_award_value': 1082804.87,
#   'Count_award_value': 26},
#  {'Year': 2018,
#   'Country': 'Slovenia',
#   'CPV_division': '03',
#   'Avg_award_value': 21371.4,
#   'Max_award_value': 1152850,
#   'Count_award_value': 266},
#  {'Year': 2015,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 258749.31,
#   'Max_award_value': 53000000,
#   'Count_award_value': 445},
#  {'Year': 2010,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 244362.49,
#   'Max_award_value': 4270400,
#   'Count_award_value': 36},
#  {'Year': 2009,
#   'Country': 'Ireland',
#   'CPV_division': '03',
#   'Avg_award_value': 192038.17,
#   'Max_award_value': 345762,
#   'Count_award_value': 7},
#  {'Year': 2017,
#   'CPV_division': '03',
#   'Avg_award_value': 876054.03,
#   'Max_award_value': 36608581.05,
#   'Count_award_value': 101},
#  {'Year': 2018,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 1483045.08,
#   'Max_award_value': 472651692.39,
#   'Count_award_value': 1737},
#  {'Year': 2012,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 1127360.24,
#   'Max_award_value': 13200024.51,
#   'Count_award_value': 206},
#  {'Year': 2011,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 384941.1,
#   'Max_award_value': 384941.1,
#   'Count_award_value': 1},
#  {'Year': 2014,
#   'Country': 'Finland',
#   'CPV_division': '03',
#   'Avg_award_value': 27520.94,
#   'Max_award_value': 98000,
#   'Count_award_value': 16},
#  {'Year': 2011,
#   'CPV_division': '03',
#   'Avg_award_value': 1048450.33,
#   'Max_award_value': 7335297.51,
#   'Count_award_value': 57},
#  {'Year': 2018,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 192830.0,
#   'Max_award_value': 198660,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 14636103.62,
#   'Max_award_value': 37667975.63,
#   'Count_award_value': 4},
#  {'Year': 2017,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 1082175.28,
#   'Max_award_value': 22234279.8,
#   'Count_award_value': 195},
#  {'Year': 2012,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 177069.55,
#   'Max_award_value': 3349283.74,
#   'Count_award_value': 62},
#  {'Year': 2012,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 676628.05,
#   'Max_award_value': 12920506.24,
#   'Count_award_value': 309},
#  {'Year': 2013,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1200764.91,
#   'Max_award_value': 26616054.31,
#   'Count_award_value': 318},
#  {'Year': 2016,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 180809.01,
#   'Max_award_value': 967741.94,
#   'Count_award_value': 11},
#  {'Year': 2011,
#   'CPV_division': '09',
#   'Avg_award_value': 128252872.51,
#   'Max_award_value': 1497902935.89,
#   'Count_award_value': 95},
#  {'Year': 2017,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 344126.87,
#   'Max_award_value': 55000000,
#   'Count_award_value': 561},
#  {'Year': 2016,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1099654.48,
#   'Max_award_value': 66000550,
#   'Count_award_value': 893},
#  {'Year': 2016,
#   'Country': 'Ireland',
#   'CPV_division': '03',
#   'Avg_award_value': 1650000.0,
#   'Max_award_value': 3000000,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 82572.7,
#   'Max_award_value': 2271174.96,
#   'Count_award_value': 222},
#  {'Year': 2011,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 788023.71,
#   'Max_award_value': 41433716,
#   'Count_award_value': 83},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 4473714.54,
#   'Max_award_value': 100000000,
#   'Count_award_value': 216},
#  {'Year': 2014,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 1938773.68,
#   'Max_award_value': 24742714.02,
#   'Count_award_value': 116},
#  {'Year': 2010,
#   'Country': 'Finland',
#   'CPV_division': '03',
#   'Avg_award_value': 91627.2,
#   'Max_award_value': 224800,
#   'Count_award_value': 5},
#  {'Year': 2016,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 4594034.25,
#   'Max_award_value': 260000000,
#   'Count_award_value': 503},
#  {'Year': 2018,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 81025.15,
#   'Max_award_value': 1730000,
#   'Count_award_value': 187},
#  {'Year': 2013,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 1267418.08,
#   'Max_award_value': 9566640,
#   'Count_award_value': 67},
#  {'Year': 2014,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 1909087.94,
#   'Max_award_value': 40992145.03,
#   'Count_award_value': 223},
#  {'Year': 2009,
#   'Country': 'Sweden',
#   'CPV_division': '03',
#   'Avg_award_value': 470849.7,
#   'Max_award_value': 470849.7,
#   'Count_award_value': 3},
#  {'Year': 2013,
#   'Country': 'Belgium',
#   'CPV_division': '03',
#   'Avg_award_value': 111901.89,
#   'Max_award_value': 629756,
#   'Count_award_value': 15},
#  {'Year': 2010,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 23486.78,
#   'Max_award_value': 23486.78,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Iceland',
#   'CPV_division': '09',
#   'Avg_award_value': 2388726.44,
#   'Max_award_value': 2388726.44,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'CPV_division': '03',
#   'Avg_award_value': 505501.75,
#   'Max_award_value': 2755428.19,
#   'Count_award_value': 27},
#  {'Year': 2018,
#   'Country': 'Estonia',
#   'CPV_division': '03',
#   'Avg_award_value': 149717.3,
#   'Max_award_value': 1600000,
#   'Count_award_value': 52},
#  {'Year': 2018,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 1870785.67,
#   'Max_award_value': 59872208.97,
#   'Count_award_value': 135},
#  {'Year': 2014,
#   'Country': 'France',
#   'CPV_division': '09',
#   'Avg_award_value': 3750808.13,
#   'Max_award_value': 249439200,
#   'Count_award_value': 377},
#  {'Year': 2013,
#   'Country': 'Finland',
#   'CPV_division': '09',
#   'Avg_award_value': 2007913.75,
#   'Max_award_value': 12900000,
#   'Count_award_value': 12},
#  {'Year': 2012,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 737519.61,
#   'Max_award_value': 5903738,
#   'Count_award_value': 45},
#  {'Year': 2009,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 381312.5,
#   'Max_award_value': 381312.5,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 1368571.99,
#   'Max_award_value': 4245999.82,
#   'Count_award_value': 13},
#  {'Year': 2016,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 208598.19,
#   'Max_award_value': 208598.19,
#   'Count_award_value': 1},
#  {'Year': 2017,
#   'Country': 'Malta',
#   'CPV_division': '03',
#   'Avg_award_value': 12710.36,
#   'Max_award_value': 17379.08,
#   'Count_award_value': 3},
#  {'Year': 2015,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 2080251.27,
#   'Max_award_value': 23895141.6,
#   'Count_award_value': 89},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 352107.96,
#   'Max_award_value': 1700000,
#   'Count_award_value': 24},
#  {'Year': 2011,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 1006877.96,
#   'Max_award_value': 1027976.58,
#   'Count_award_value': 10},
#  {'Year': 2015,
#   'Country': 'Spain',
#   'CPV_division': '03',
#   'Avg_award_value': 356188.33,
#   'Max_award_value': 6709248,
#   'Count_award_value': 54},
#  {'Year': 2013,
#   'Country': 'Croatia',
#   'CPV_division': '03',
#   'Avg_award_value': 50135.61,
#   'Max_award_value': 131800.4,
#   'Count_award_value': 5},
#  {'Year': 2012,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 2451332.94,
#   'Max_award_value': 74247059.53,
#   'Count_award_value': 286},
#  {'Year': 2009,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 109579.25,
#   'Max_award_value': 2014000,
#   'Count_award_value': 226},
#  {'Year': 2018,
#   'Country': 'Austria',
#   'CPV_division': '03',
#   'Avg_award_value': 365261.17,
#   'Max_award_value': 1298440,
#   'Count_award_value': 9},
#  {'Year': 2012,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 123801.91,
#   'Max_award_value': 678353,
#   'Count_award_value': 23},
#  {'Year': 2015,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1295834.77,
#   'Max_award_value': 46330599.01,
#   'Count_award_value': 366},
#  {'Year': 2016,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 23610.11,
#   'Max_award_value': 94414.47,
#   'Count_award_value': 14},
#  {'Year': 2017,
#   'Country': 'Switzerland',
#   'CPV_division': '09',
#   'Avg_award_value': 701165.55,
#   'Max_award_value': 2174830.31,
#   'Count_award_value': 11},
#  {'Year': 2014,
#   'Country': 'Finland',
#   'CPV_division': '09',
#   'Avg_award_value': 605040.38,
#   'Max_award_value': 1590082,
#   'Count_award_value': 8},
#  {'Year': 2012,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 504341.08,
#   'Max_award_value': 695642.87,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 3266211.09,
#   'Max_award_value': 174921450.55,
#   'Count_award_value': 293},
#  {'Year': 2011,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 10589751.16,
#   'Max_award_value': 18790432.99,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 57824.25,
#   'Max_award_value': 491956.03,
#   'Count_award_value': 38},
#  {'Year': 2010,
#   'Country': 'Ireland',
#   'CPV_division': '03',
#   'Avg_award_value': 135000.0,
#   'Max_award_value': 135000,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Austria',
#   'CPV_division': '03',
#   'Avg_award_value': 305769.42,
#   'Max_award_value': 654792.94,
#   'Count_award_value': 3},
#  {'Year': 2012,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 906641.69,
#   'Max_award_value': 2573499.84,
#   'Count_award_value': 6},
#  {'Year': 2017,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 11921699.45,
#   'Max_award_value': 190000000,
#   'Count_award_value': 17},
#  {'Year': 2017,
#   'Country': 'Sweden',
#   'CPV_division': '03',
#   'Avg_award_value': 316557.15,
#   'Max_award_value': 3928650.64,
#   'Count_award_value': 47},
#  {'Year': 2015,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 872747.7,
#   'Max_award_value': 7239867.54,
#   'Count_award_value': 17},
#  {'Year': 2013,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 3573100.03,
#   'Max_award_value': 43036115.38,
#   'Count_award_value': 16},
#  {'Year': 2013,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 84248.35,
#   'Max_award_value': 1605888.86,
#   'Count_award_value': 253},
#  {'Year': 2014,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 6845004.85,
#   'Max_award_value': 24303413.64,
#   'Count_award_value': 7},
#  {'Year': 2017,
#   'Country': 'Austria',
#   'CPV_division': '03',
#   'Avg_award_value': 91926.48,
#   'Max_award_value': 463725,
#   'Count_award_value': 12},
#  {'Year': 2015,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 81415.5,
#   'Max_award_value': 348200,
#   'Count_award_value': 46},
#  {'Year': 2014,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 623759.19,
#   'Max_award_value': 858507.27,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 115865.82,
#   'Max_award_value': 644419.71,
#   'Count_award_value': 10},
#  {'Year': 2018,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 62548.66,
#   'Max_award_value': 574200,
#   'Count_award_value': 25},
#  {'Year': 2016,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1004376.57,
#   'Max_award_value': 5679865,
#   'Count_award_value': 14},
#  {'Year': 2018,
#   'Country': 'Croatia',
#   'CPV_division': '03',
#   'Avg_award_value': 81372.12,
#   'Max_award_value': 473428.49,
#   'Count_award_value': 11},
#  {'Year': 2014,
#   'Country': 'Malta',
#   'CPV_division': '09',
#   'Avg_award_value': 498034.4,
#   'Max_award_value': 1600000,
#   'Count_award_value': 7},
#  {'Year': 2013,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 24866399.29,
#   'Max_award_value': 962278656.66,
#   'Count_award_value': 360},
#  {'Year': 2012,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 81568.63,
#   'Max_award_value': 1846375,
#   'Count_award_value': 339},
#  {'Year': 2011,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 233358.41,
#   'Max_award_value': 9766000,
#   'Count_award_value': 303},
#  {'Year': 2014,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 18995594.71,
#   'Max_award_value': 34000000,
#   'Count_award_value': 4},
#  {'Year': 2015,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 2000153.54,
#   'Max_award_value': 97481000,
#   'Count_award_value': 279},
#  {'Year': 2015,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 2777108.98,
#   'Max_award_value': 65000000,
#   'Count_award_value': 32},
#  {'Year': 2010,
#   'CPV_division': '09',
#   'Avg_award_value': 16744849.03,
#   'Max_award_value': 181852093.63,
#   'Count_award_value': 66},
#  {'Year': 2009,
#   'Country': 'Estonia',
#   'CPV_division': '03',
#   'Avg_award_value': 284087.28,
#   'Max_award_value': 332340.57,
#   'Count_award_value': 2},
#  {'Year': 2017,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1049529.71,
#   'Max_award_value': 33563288.16,
#   'Count_award_value': 942},
#  {'Year': 2018,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 1222299.03,
#   'Max_award_value': 50000000,
#   'Count_award_value': 251},
#  {'Year': 2009,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 881518.49,
#   'Max_award_value': 34542992,
#   'Count_award_value': 73},
#  {'Year': 2009,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 3719709.29,
#   'Max_award_value': 20175126.05,
#   'Count_award_value': 46},
#  {'Year': 2017,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 1230000.0,
#   'Max_award_value': 1230000,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 29893220.66,
#   'Max_award_value': 123803257.56,
#   'Count_award_value': 5},
#  {'Year': 2017,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 45076.85,
#   'Max_award_value': 1284356.54,
#   'Count_award_value': 46},
#  {'Year': 2014,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 183554.71,
#   'Max_award_value': 460560,
#   'Count_award_value': 30},
#  {'Year': 2016,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 271137.61,
#   'Max_award_value': 4697952.9,
#   'Count_award_value': 46},
#  {'Year': 2012,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 64168.87,
#   'Max_award_value': 827190.59,
#   'Count_award_value': 56},
#  {'Year': 2012,
#   'Country': 'Switzerland',
#   'CPV_division': '09',
#   'Avg_award_value': 10939.57,
#   'Max_award_value': 261192.23,
#   'Count_award_value': 24},
#  {'Year': 2012,
#   'Country': 'Slovenia',
#   'CPV_division': '03',
#   'Avg_award_value': 17573.94,
#   'Max_award_value': 68640,
#   'Count_award_value': 16},
#  {'Year': 2013,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 223974.21,
#   'Max_award_value': 501519.18,
#   'Count_award_value': 4},
#  {'Year': 2018,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 186311.98,
#   'Max_award_value': 7796425.47,
#   'Count_award_value': 900},
#  {'Year': 2012,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 385407.67,
#   'Max_award_value': 761883.37,
#   'Count_award_value': 3},
#  {'Year': 2011,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 71888.13,
#   'Max_award_value': 2040000,
#   'Count_award_value': 369},
#  {'Year': 2011,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 828937.13,
#   'Max_award_value': 86704121.15,
#   'Count_award_value': 1578},
#  {'Year': 2016,
#   'Country': 'Finland',
#   'CPV_division': '09',
#   'Avg_award_value': 3347197.14,
#   'Max_award_value': 60000000,
#   'Count_award_value': 56},
#  {'Year': 2010,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 1436835.41,
#   'Max_award_value': 5403639.5,
#   'Count_award_value': 25},
#  {'Year': 2015,
#   'Country': 'Croatia',
#   'CPV_division': '03',
#   'Avg_award_value': 1110893.38,
#   'Max_award_value': 18155873.62,
#   'Count_award_value': 31},
#  {'Year': 2012,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 14392073.53,
#   'Max_award_value': 56020527.43,
#   'Count_award_value': 7},
#  {'Year': 2017,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 64959.3,
#   'Max_award_value': 682151.45,
#   'Count_award_value': 350},
#  {'Year': 2009,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 1293721.12,
#   'Max_award_value': 24493958,
#   'Count_award_value': 65},
#  {'Year': 2009,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1451886.39,
#   'Max_award_value': 59143139.5,
#   'Count_award_value': 575},
#  {'Year': 2012,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1658429.84,
#   'Max_award_value': 106429260.2,
#   'Count_award_value': 317},
#  {'Year': 2010,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 95726.44,
#   'Max_award_value': 2281525,
#   'Count_award_value': 243},
#  {'Year': 2017,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 86416.61,
#   'Max_award_value': 1487655.46,
#   'Count_award_value': 91},
#  {'Year': 2016,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 1662295.86,
#   'Max_award_value': 30000000,
#   'Count_award_value': 159},
#  {'Year': 2011,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 594871.9,
#   'Max_award_value': 699064.66,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 651368.24,
#   'Max_award_value': 48477818.65,
#   'Count_award_value': 906},
#  {'Year': 2018,
#   'Country': 'Ireland',
#   'CPV_division': '03',
#   'Avg_award_value': 173058.84,
#   'Max_award_value': 365000,
#   'Count_award_value': 7},
#  {'Year': 2013,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 125320.22,
#   'Max_award_value': 2239478.62,
#   'Count_award_value': 117},
#  {'Year': 2014,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 68090.33,
#   'Max_award_value': 1217580.76,
#   'Count_award_value': 248},
#  {'Year': 2014,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 89157.77,
#   'Max_award_value': 307589.53,
#   'Count_award_value': 16},
#  {'Year': 2015,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 1171163.25,
#   'Max_award_value': 115523381.24,
#   'Count_award_value': 1436},
#  {'Year': 2013,
#   'Country': 'France',
#   'CPV_division': '09',
#   'Avg_award_value': 3265317.47,
#   'Max_award_value': 90677600,
#   'Count_award_value': 398},
#  {'Year': 2011,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 252082.29,
#   'Max_award_value': 2374042.18,
#   'Count_award_value': 48},
#  {'Year': 2010,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 44340.57,
#   'Max_award_value': 343634.15,
#   'Count_award_value': 24},
#  {'Year': 2010,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 129260.26,
#   'Max_award_value': 3200000,
#   'Count_award_value': 107},
#  {'Year': 2017,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 2332484.65,
#   'Max_award_value': 130000000,
#   'Count_award_value': 644},
#  {'Year': 2017,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 52938.79,
#   'Max_award_value': 714991.2,
#   'Count_award_value': 31},
#  {'Year': 2018,
#   'Country': 'Iceland',
#   'CPV_division': '03',
#   'Avg_award_value': 87230.98,
#   'Max_award_value': 299402.74,
#   'Count_award_value': 10},
#  {'Year': 2018,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 649946.36,
#   'Max_award_value': 1072961.39,
#   'Count_award_value': 2},
#  {'Year': 2018,
#   'Country': 'Norway',
#   'CPV_division': '09',
#   'Avg_award_value': 25590971.05,
#   'Max_award_value': 800000000,
#   'Count_award_value': 43},
#  {'Year': 2012,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 358244.78,
#   'Max_award_value': 403025.38,
#   'Count_award_value': 3},
#  {'Year': 2015,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 830773.42,
#   'Max_award_value': 7910626.45,
#   'Count_award_value': 131},
#  {'Year': 2017,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1412164.65,
#   'Max_award_value': 49060217.35,
#   'Count_award_value': 479},
#  {'Year': 2011,
#   'Country': 'Finland',
#   'CPV_division': '03',
#   'Avg_award_value': 123154.61,
#   'Max_award_value': 1200000,
#   'Count_award_value': 29},
#  {'Year': 2011,
#   'Country': 'Ireland',
#   'CPV_division': '03',
#   'Avg_award_value': 800338.64,
#   'Max_award_value': 2000000,
#   'Count_award_value': 4},
#  {'Year': 2016,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 235440.0,
#   'Max_award_value': 236160,
#   'Count_award_value': 2},
#  {'Year': 2017,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 21001.83,
#   'Max_award_value': 323612.94,
#   'Count_award_value': 65},
#  {'Year': 2016,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 55893.28,
#   'Max_award_value': 940693.75,
#   'Count_award_value': 266},
#  {'Year': 2018,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 319744.79,
#   'Max_award_value': 2900000,
#   'Count_award_value': 42},
#  {'Year': 2018,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 3085318.7,
#   'Max_award_value': 45271145.11,
#   'Count_award_value': 149},
#  {'Year': 2016,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 1549335.34,
#   'Max_award_value': 35816261.87,
#   'Count_award_value': 188},
#  {'Year': 2017,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 1838346.63,
#   'Max_award_value': 77057894.39,
#   'Count_award_value': 232},
#  {'Year': 2009,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 4962910.17,
#   'Max_award_value': 4962910.17,
#   'Count_award_value': 1},
#  {'Year': 2013,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 985957.01,
#   'Max_award_value': 2344700,
#   'Count_award_value': 3},
#  {'Year': 2017,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 3614903.91,
#   'Max_award_value': 164184466.67,
#   'Count_award_value': 101},
#  {'Year': 2013,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 16269967.3,
#   'Max_award_value': 210000000,
#   'Count_award_value': 237},
#  {'Year': 2016,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 332800.6,
#   'Max_award_value': 1344000,
#   'Count_award_value': 5},
#  {'Year': 2014,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 64397.61,
#   'Max_award_value': 647857.21,
#   'Count_award_value': 56},
#  {'Year': 2014,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 2907763.44,
#   'Max_award_value': 207276736,
#   'Count_award_value': 268},
#  {'Year': 2012,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1233903.63,
#   'Max_award_value': 65363296,
#   'Count_award_value': 728},
#  {'Year': 2009,
#   'CPV_division': '03',
#   'Avg_award_value': 1021953.31,
#   'Max_award_value': 15713740.54,
#   'Count_award_value': 20},
#  {'Year': 2012,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 43911.15,
#   'Max_award_value': 634612.91,
#   'Count_award_value': 36},
#  {'Year': 2018,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 928436.2,
#   'Max_award_value': 7447567.47,
#   'Count_award_value': 13},
#  {'Year': 2013,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 1748982.0,
#   'Max_award_value': 4810424,
#   'Count_award_value': 4},
#  {'Year': 2009,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 3371315.45,
#   'Max_award_value': 301210368,
#   'Count_award_value': 270},
#  {'Year': 2010,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1021388.68,
#   'Max_award_value': 27053220,
#   'Count_award_value': 440},
#  {'Year': 2010,
#   'Country': 'Malta',
#   'CPV_division': '03',
#   'Avg_award_value': 290017.23,
#   'Max_award_value': 378813.56,
#   'Count_award_value': 4},
#  {'Year': 2009,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 73581.89,
#   'Max_award_value': 333895,
#   'Count_award_value': 13},
#  {'Year': 2013,
#   'Country': 'Norway',
#   'CPV_division': '09',
#   'Avg_award_value': 256190.2,
#   'Max_award_value': 256190.2,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Estonia',
#   'CPV_division': '03',
#   'Avg_award_value': 34903.91,
#   'Max_award_value': 40450.7,
#   'Count_award_value': 4},
#  {'Year': 2017,
#   'CPV_division': '09',
#   'Avg_award_value': 48564013.55,
#   'Max_award_value': 1220286035.05,
#   'Count_award_value': 131},
#  {'Year': 2013,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 58970.82,
#   'Max_award_value': 447440.13,
#   'Count_award_value': 64},
#  {'Year': 2017,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 3450468.19,
#   'Max_award_value': 739809129.24,
#   'Count_award_value': 515},
#  {'Year': 2009,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 254734.81,
#   'Max_award_value': 1702125,
#   'Count_award_value': 59},
#  {'Year': 2017,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 240728.31,
#   'Max_award_value': 7291880,
#   'Count_award_value': 84},
#  {'Year': 2010,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 717852.76,
#   'Max_award_value': 1422960,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 91420.83,
#   'Max_award_value': 1829105.98,
#   'Count_award_value': 285},
#  {'Year': 2013,
#   'CPV_division': '09',
#   'Avg_award_value': 57402566.85,
#   'Max_award_value': 854861879.75,
#   'Count_award_value': 46},
#  {'Year': 2016,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 1776457.43,
#   'Max_award_value': 47004320,
#   'Count_award_value': 97},
#  {'Year': 2015,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 1131243.87,
#   'Max_award_value': 3945266.46,
#   'Count_award_value': 76},
#  {'Year': 2013,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 8184975.61,
#   'Max_award_value': 20858000,
#   'Count_award_value': 4},
#  {'Year': 2018,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 165629.82,
#   'Max_award_value': 400309.22,
#   'Count_award_value': 15},
#  {'Year': 2014,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 1615509.51,
#   'Max_award_value': 13500000,
#   'Count_award_value': 64},
#  {'Year': 2014,
#   'Country': 'Croatia',
#   'CPV_division': '03',
#   'Avg_award_value': 741658.21,
#   'Max_award_value': 17036964.27,
#   'Count_award_value': 32},
#  {'Year': 2010,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 12151628.0,
#   'Max_award_value': 46641672,
#   'Count_award_value': 4},
#  {'Year': 2018,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1853636.05,
#   'Max_award_value': 114214708.13,
#   'Count_award_value': 395},
#  {'Year': 2010,
#   'Country': 'Finland',
#   'CPV_division': '09',
#   'Avg_award_value': 2014510.49,
#   'Max_award_value': 18000000,
#   'Count_award_value': 18},
#  {'Year': 2015,
#   'Country': 'Malta',
#   'CPV_division': '09',
#   'Avg_award_value': 3327601.25,
#   'Max_award_value': 6431652.5,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 90119.79,
#   'Max_award_value': 90119.79,
#   'Count_award_value': 1},
#  {'Year': 2011,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 751446.15,
#   'Max_award_value': 1785365.9,
#   'Count_award_value': 3},
#  {'Year': 2016,
#   'CPV_division': '09',
#   'Avg_award_value': 627706628.37,
#   'Max_award_value': 20665711451.56,
#   'Count_award_value': 148},
#  {'Year': 2011,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 2946273.17,
#   'Max_award_value': 2946273.17,
#   'Count_award_value': 1},
#  {'Year': 2017,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 250962.05,
#   'Max_award_value': 38347479.29,
#   'Count_award_value': 1209},
#  {'Year': 2014,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 30899.94,
#   'Max_award_value': 498921.41,
#   'Count_award_value': 44},
#  {'Year': 2015,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 426481.83,
#   'Max_award_value': 777615.4,
#   'Count_award_value': 2},
#  {'Year': 2018,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 257093.07,
#   'Max_award_value': 5500000,
#   'Count_award_value': 89},
#  {'Year': 2017,
#   'Country': 'Estonia',
#   'CPV_division': '03',
#   'Avg_award_value': 18571.82,
#   'Max_award_value': 38550,
#   'Count_award_value': 8},
#  {'Year': 2012,
#   'Country': 'Norway',
#   'CPV_division': '09',
#   'Avg_award_value': 290509.09,
#   'Max_award_value': 608687.51,
#   'Count_award_value': 6},
#  {'Year': 2018,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 190873.82,
#   'Max_award_value': 5594148,
#   'Count_award_value': 507},
#  {'Year': 2017,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 533398.42,
#   'Max_award_value': 3063453.07,
#   'Count_award_value': 28},
#  {'Year': 2012,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 877725.15,
#   'Max_award_value': 48614786.79,
#   'Count_award_value': 338},
#  {'Year': 2013,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 43677.9,
#   'Max_award_value': 368614.09,
#   'Count_award_value': 36},
#  {'Year': 2016,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 4267010.96,
#   'Max_award_value': 141513178.02,
#   'Count_award_value': 200},
#  {'Year': 2011,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 1070427.8,
#   'Max_award_value': 14398326.35,
#   'Count_award_value': 173},
#  {'Year': 2016,
#   'Country': 'Switzerland',
#   'CPV_division': '03',
#   'Avg_award_value': 413066.18,
#   'Max_award_value': 492090.98,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 750556.01,
#   'Max_award_value': 26125617.1,
#   'Count_award_value': 562},
#  {'Year': 2017,
#   'Country': 'Norway',
#   'CPV_division': '09',
#   'Avg_award_value': 1472304.35,
#   'Max_award_value': 21527134.95,
#   'Count_award_value': 31},
#  {'Year': 2017,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 3842847.92,
#   'Max_award_value': 129976600,
#   'Count_award_value': 105},
#  {'Year': 2016,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 671037.24,
#   'Max_award_value': 5698578.71,
#   'Count_award_value': 18},
#  {'Year': 2017,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 361541.73,
#   'Max_award_value': 617000,
#   'Count_award_value': 10},
#  {'Year': 2013,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 412505.61,
#   'Max_award_value': 797860,
#   'Count_award_value': 11},
#  {'Year': 2011,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 779479.33,
#   'Max_award_value': 6375042,
#   'Count_award_value': 62},
#  {'Year': 2011,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 120000.0,
#   'Max_award_value': 120000,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 7792157.46,
#   'Max_award_value': 674036231.63,
#   'Count_award_value': 217},
#  {'Year': 2012,
#   'CPV_division': '09',
#   'Avg_award_value': 29837930.13,
#   'Max_award_value': 895334640.57,
#   'Count_award_value': 99},
#  {'Year': 2014,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 47105.18,
#   'Max_award_value': 144701,
#   'Count_award_value': 10},
#  {'Year': 2018,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 384972.89,
#   'Max_award_value': 901519.85,
#   'Count_award_value': 7},
#  {'Year': 2017,
#   'Country': 'Malta',
#   'CPV_division': '09',
#   'Avg_award_value': 1245000.0,
#   'Max_award_value': 1245000,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 902255.01,
#   'Max_award_value': 1909440,
#   'Count_award_value': 6},
#  {'Year': 2010,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 1855598.78,
#   'Max_award_value': 35868000,
#   'Count_award_value': 74},
#  {'Year': 2018,
#   'CPV_division': '03',
#   'Avg_award_value': 2172146.37,
#   'Max_award_value': 12558396.13,
#   'Count_award_value': 185},
#  {'Year': 2011,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 826026.12,
#   'Max_award_value': 12600000,
#   'Count_award_value': 71},
#  {'Year': 2014,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 647148.91,
#   'Max_award_value': 2546218,
#   'Count_award_value': 17},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '03',
#   'Avg_award_value': 560972.05,
#   'Max_award_value': 2184440,
#   'Count_award_value': 12},
#  {'Year': 2016,
#   'Country': 'Malta',
#   'CPV_division': '09',
#   'Avg_award_value': 3253644.05,
#   'Max_award_value': 8918908,
#   'Count_award_value': 3},
#  {'Year': 2012,
#   'Country': 'Sweden',
#   'CPV_division': '03',
#   'Avg_award_value': 244770.99,
#   'Max_award_value': 430004.25,
#   'Count_award_value': 3},
#  {'Year': 2010,
#   'Country': 'Cyprus',
#   'CPV_division': '03',
#   'Avg_award_value': 132257.23,
#   'Max_award_value': 315544,
#   'Count_award_value': 10},
#  {'Year': 2017,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 57064.33,
#   'Max_award_value': 342243.8,
#   'Count_award_value': 22},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 654410.8,
#   'Max_award_value': 20000000,
#   'Count_award_value': 148},
#  {'Year': 2014,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 183430.2,
#   'Max_award_value': 762666,
#   'Count_award_value': 18},
#  {'Year': 2013,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 392229.88,
#   'Max_award_value': 9460800,
#   'Count_award_value': 323},
#  {'Year': 2013,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 2005933.98,
#   'Max_award_value': 12429089,
#   'Count_award_value': 105},
#  {'Year': 2018,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 2471140.75,
#   'Max_award_value': 49400000,
#   'Count_award_value': 72},
#  {'Year': 2013,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 2622517.08,
#   'Max_award_value': 290168136.01,
#   'Count_award_value': 157},
#  {'Year': 2015,
#   'Country': 'Czechia',
#   'CPV_division': '03',
#   'Avg_award_value': 54579.62,
#   'Max_award_value': 509663.11,
#   'Count_award_value': 48},
#  {'Year': 2011,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 2268539.05,
#   'Max_award_value': 87193828.97,
#   'Count_award_value': 263},
#  {'Year': 2013,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 2736511.8,
#   'Max_award_value': 107791289.12,
#   'Count_award_value': 291},
#  {'Year': 2015,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 666750.88,
#   'Max_award_value': 60000000,
#   'Count_award_value': 698},
#  {'Year': 2014,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 140689.48,
#   'Max_award_value': 6099056.19,
#   'Count_award_value': 121},
#  {'Year': 2016,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 589812.45,
#   'Max_award_value': 32765914.33,
#   'Count_award_value': 419},
#  {'Year': 2017,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 64939.81,
#   'Max_award_value': 64939.81,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 767671.4,
#   'Max_award_value': 82040434.72,
#   'Count_award_value': 1268},
#  {'Year': 2018,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 210238.7,
#   'Max_award_value': 841200,
#   'Count_award_value': 18},
#  {'Year': 2018,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 192320.65,
#   'Max_award_value': 2075255.9,
#   'Count_award_value': 19},
#  {'Year': 2014,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 97423.16,
#   'Max_award_value': 97423.16,
#   'Count_award_value': 1},
#  {'Year': 2014,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 2084973.8,
#   'Max_award_value': 25259144,
#   'Count_award_value': 63},
#  {'Year': 2009,
#   'Country': 'Switzerland',
#   'CPV_division': '03',
#   'Avg_award_value': 266543.08,
#   'Max_award_value': 333504.7,
#   'Count_award_value': 2},
#  {'Year': 2018,
#   'Country': 'Cyprus',
#   'CPV_division': '03',
#   'Avg_award_value': 428970.0,
#   'Max_award_value': 428970,
#   'Count_award_value': 1},
#  {'Year': 2013,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 1470640.33,
#   'Max_award_value': 6791910,
#   'Count_award_value': 15},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '09',
#   'Avg_award_value': 1137027.01,
#   'Max_award_value': 171993977.2,
#   'Count_award_value': 1503},
#  {'Year': 2018,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 11644954.88,
#   'Max_award_value': 484542826.08,
# ...
#   'Max_award_value': 5444572,
#   'Count_award_value': 18},
#  {'Year': 2011,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 567111.68,
#   'Max_award_value': 2425410,
#   'Count_award_value': 26},
#  {'Year': 2011,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 1341047.29,
#   'Max_award_value': 149181028.73,
#   'Count_award_value': 184},
#  {'Year': 2016,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 2931865.49,
#   'Max_award_value': 5184125,
#   'Count_award_value': 11},
#  {'Year': 2017,
#   'Country': 'Greece',
#   'CPV_division': '03',
#   'Avg_award_value': 91593.5,
#   'Max_award_value': 889807.9,
#   'Count_award_value': 23},
#  {'Year': 2012,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 2488346.72,
#   'Max_award_value': 325760623.73,
#   'Count_award_value': 506},
#  {'Year': 2013,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 124334.85,
#   'Max_award_value': 264712.7,
#   'Count_award_value': 4},
#  {'Year': 2013,
#   'Country': 'Portugal',
#   'CPV_division': '03',
#   'Avg_award_value': 164588.59,
#   'Max_award_value': 1130770.9,
#   'Count_award_value': 60},
#  {'Year': 2015,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 255292.56,
#   'Max_award_value': 255292.56,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 2945459.63,
#   'Max_award_value': 35392000,
#   'Count_award_value': 104},
#  {'Year': 2016,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 14026474.36,
#   'Max_award_value': 1173063528.72,
#   'Count_award_value': 467},
#  {'Year': 2016,
#   'Country': 'France',
#   'CPV_division': '09',
#   'Avg_award_value': 9917365.59,
#   'Max_award_value': 1606508844,
#   'Count_award_value': 1059},
#  {'Year': 2009,
#   'Country': 'Belgium',
#   'CPV_division': '03',
#   'Avg_award_value': 220303.69,
#   'Max_award_value': 410892.56,
#   'Count_award_value': 5},
#  {'Year': 2010,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 1875441.29,
#   'Max_award_value': 29040220.71,
#   'Count_award_value': 185},
#  {'Year': 2009,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 212386.36,
#   'Max_award_value': 6000000,
#   'Count_award_value': 186},
#  {'Year': 2015,
#   'Country': 'Slovakia',
#   'CPV_division': '09',
#   'Avg_award_value': 4973812.66,
#   'Max_award_value': 164184466.67,
#   'Count_award_value': 133},
#  {'Year': 2014,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 203119.92,
#   'Max_award_value': 6301445,
#   'Count_award_value': 181},
#  {'Year': 2011,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 848353.86,
#   'Max_award_value': 9338848,
#   'Count_award_value': 52},
#  {'Year': 2016,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 476544.3,
#   'Max_award_value': 12999600,
#   'Count_award_value': 614},
#  {'Year': 2017,
#   'Country': 'Finland',
#   'CPV_division': '09',
#   'Avg_award_value': 4245319.57,
#   'Max_award_value': 112000000,
#   'Count_award_value': 61},
#  {'Year': 2011,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 397982.81,
#   'Max_award_value': 1216152,
#   'Count_award_value': 20},
#  {'Year': 2015,
#   'Country': 'Croatia',
#   'CPV_division': '09',
#   'Avg_award_value': 1167279.29,
#   'Max_award_value': 37678461.19,
#   'Count_award_value': 231},
#  {'Year': 2012,
#   'Country': 'Belgium',
#   'CPV_division': '09',
#   'Avg_award_value': 3436988.13,
#   'Max_award_value': 57134900,
#   'Count_award_value': 126},
#  {'Year': 2013,
#   'CPV_division': '03',
#   'Avg_award_value': 419110.79,
#   'Max_award_value': 1507194.5,
#   'Count_award_value': 19},
#  {'Year': 2013,
#   'Country': 'Denmark',
#   'CPV_division': '09',
#   'Avg_award_value': 1164714.92,
#   'Max_award_value': 4654175.57,
#   'Count_award_value': 10},
#  {'Year': 2009,
#   'Country': 'Hungary',
#   'CPV_division': '03',
#   'Avg_award_value': 39313.02,
#   'Max_award_value': 342434.87,
#   'Count_award_value': 39},
#  {'Year': 2014,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 524222.49,
#   'Max_award_value': 1500000,
#   'Count_award_value': 11},
#  {'Year': 2017,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 154163.55,
#   'Max_award_value': 1295239.8,
#   'Count_award_value': 57},
#  {'Year': 2018,
#   'Country': 'Poland',
#   'CPV_division': '03',
#   'Avg_award_value': 72769.62,
#   'Max_award_value': 1472549.19,
#   'Count_award_value': 210},
#  {'Year': 2016,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 266481.35,
#   'Max_award_value': 1239669.42,
#   'Count_award_value': 10},
#  {'Year': 2018,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 264962.82,
#   'Max_award_value': 5176909.56,
#   'Count_award_value': 50},
#  {'Year': 2009,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 2685214.01,
#   'Max_award_value': 25000000,
#   'Count_award_value': 35},
#  {'Year': 2017,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 1017659.92,
#   'Max_award_value': 25318745.93,
#   'Count_award_value': 98},
#  {'Year': 2017,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 818616.41,
#   'Max_award_value': 10227187.68,
#   'Count_award_value': 101},
#  {'Year': 2009,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 2896971.17,
#   'Max_award_value': 76028960,
#   'Count_award_value': 277},
#  {'Year': 2012,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 74973.21,
#   'Max_award_value': 253591.29,
#   'Count_award_value': 12},
#  {'Year': 2013,
#   'Country': 'Malta',
#   'CPV_division': '09',
#   'Avg_award_value': 1239645.65,
#   'Max_award_value': 3002275,
#   'Count_award_value': 3},
#  {'Year': 2013,
#   'Country': 'France',
#   'CPV_division': '03',
#   'Avg_award_value': 89381.96,
#   'Max_award_value': 1000000,
#   'Count_award_value': 246},
#  {'Year': 2015,
#   'CPV_division': '09',
#   'Avg_award_value': 16368092.29,
#   'Max_award_value': 1102171277.42,
#   'Count_award_value': 164},
#  {'Year': 2018,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 3001048.54,
#   'Max_award_value': 25990200,
#   'Count_award_value': 27},
#  {'Year': 2015,
#   'Country': 'France',
#   'CPV_division': '09',
#   'Avg_award_value': 1130373.48,
#   'Max_award_value': 55219000,
#   'Count_award_value': 449},
#  {'Year': 2016,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 4620533.98,
#   'Max_award_value': 26118565.24,
#   'Count_award_value': 8},
#  {'Year': 2015,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 2406363.93,
#   'Max_award_value': 63044787.83,
#   'Count_award_value': 503},
#  {'Year': 2011,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 191185.11,
#   'Max_award_value': 4143982,
#   'Count_award_value': 37},
#  {'Year': 2009,
#   'Country': 'Romania',
#   'CPV_division': '03',
#   'Avg_award_value': 131394.43,
#   'Max_award_value': 10912649.83,
#   'Count_award_value': 117},
#  {'Year': 2016,
#   'Country': 'Germany',
#   'CPV_division': '03',
#   'Avg_award_value': 166672.27,
#   'Max_award_value': 794392.52,
#   'Count_award_value': 38},
#  {'Year': 2014,
#   'Country': 'Austria',
#   'CPV_division': '03',
#   'Avg_award_value': 577587.7,
#   'Max_award_value': 577587.7,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Belgium',
#   'CPV_division': '03',
#   'Avg_award_value': 106236.75,
#   'Max_award_value': 258978.51,
#   'Count_award_value': 10},
#  {'Year': 2009,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 7489444.19,
#   'Max_award_value': 147077419.47,
#   'Count_award_value': 82},
#  {'Year': 2016,
#   'Country': 'Denmark',
#   'CPV_division': '03',
#   'Avg_award_value': 285755.56,
#   'Max_award_value': 1093000,
#   'Count_award_value': 11},
#  {'Year': 2017,
#   'Country': 'Sweden',
#   'CPV_division': '09',
#   'Avg_award_value': 1622495.23,
#   'Max_award_value': 38019199.7,
#   'Count_award_value': 60},
#  {'Year': 2015,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 263987.25,
#   'Max_award_value': 403100,
#   'Count_award_value': 4},
#  {'Year': 2015,
#   'Country': 'North Macedonia',
#   'CPV_division': '03',
#   'Avg_award_value': 374730.08,
#   'Max_award_value': 473343.38,
#   'Count_award_value': 8},
#  {'Year': 2010,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1176279.62,
#   'Max_award_value': 4622729.54,
#   'Count_award_value': 12},
#  {'Year': 2013,
#   'Country': 'Spain',
#   'CPV_division': '09',
#   'Avg_award_value': 1959779.17,
#   'Max_award_value': 61275056,
#   'Count_award_value': 605},
#  {'Year': 2014,
#   'Country': 'Estonia',
#   'CPV_division': '03',
#   'Avg_award_value': 36869.78,
#   'Max_award_value': 165460,
#   'Count_award_value': 6},
#  {'Year': 2012,
#   'Country': 'Slovakia',
#   'CPV_division': '03',
#   'Avg_award_value': 137140.0,
#   'Max_award_value': 141000,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Luxembourg',
#   'CPV_division': '09',
#   'Avg_award_value': 1616539.91,
#   'Max_award_value': 3194608,
#   'Count_award_value': 6},
#  {'Year': 2016,
#   'Country': 'Hungary',
#   'CPV_division': '09',
#   'Avg_award_value': 6487557.82,
#   'Max_award_value': 363841872.58,
#   'Count_award_value': 252},
#  {'Year': 2013,
#   'Country': 'Spain',
#   'CPV_division': '03',
#   'Avg_award_value': 232750.83,
#   'Max_award_value': 1481275,
#   'Count_award_value': 36},
#  {'Year': 2017,
#   'Country': 'Slovenia',
#   'CPV_division': '03',
#   'Avg_award_value': 15806.38,
#   'Max_award_value': 1000000,
#   'Count_award_value': 268},
#  {'Year': 2009,
#   'Country': 'Latvia',
#   'CPV_division': '09',
#   'Avg_award_value': 1121104.17,
#   'Max_award_value': 78928723.25,
#   'Count_award_value': 199},
#  {'Year': 2016,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 1537928.16,
#   'Max_award_value': 15018789.96,
#   'Count_award_value': 81},
#  {'Year': 2012,
#   'CPV_division': '03',
#   'Avg_award_value': 1451230.69,
#   'Max_award_value': 4932973.23,
#   'Count_award_value': 21},
#  {'Year': 2009,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 175755.69,
#   'Max_award_value': 313952.24,
#   'Count_award_value': 7},
#  {'Year': 2016,
#   'Country': 'Lithuania',
#   'CPV_division': '03',
#   'Avg_award_value': 336834.69,
#   'Max_award_value': 616111.49,
#   'Count_award_value': 3},
#  {'Year': 2016,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 183072.17,
#   'Max_award_value': 1947704.14,
#   'Count_award_value': 87},
#  {'Year': 2010,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 123433.64,
#   'Max_award_value': 503971.43,
#   'Count_award_value': 14},
#  {'Year': 2009,
#   'Country': 'Lithuania',
#   'CPV_division': '09',
#   'Avg_award_value': 4839983.01,
#   'Max_award_value': 34116369.32,
#   'Count_award_value': 93},
#  {'Year': 2012,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 1029869.29,
#   'Max_award_value': 7338800,
#   'Count_award_value': 74},
#  {'Year': 2018,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 14137592.04,
#   'Max_award_value': 99039756,
#   'Count_award_value': 46},
#  {'Year': 2009,
#   'Country': 'Slovenia',
#   'CPV_division': '03',
#   'Avg_award_value': 155032.09,
#   'Max_award_value': 992217.6,
#   'Count_award_value': 43},
#  {'Year': 2011,
#   'Country': 'Latvia',
#   'CPV_division': '03',
#   'Avg_award_value': 41662.7,
#   'Max_award_value': 290273.25,
#   'Count_award_value': 44},
#  {'Year': 2016,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 1198941.08,
#   'Max_award_value': 8552540,
#   'Count_award_value': 52},
#  {'Year': 2009,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 255000.0,
#   'Max_award_value': 255000,
#   'Count_award_value': 1},
#  {'Year': 2014,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 3830316.96,
#   'Max_award_value': 3830316.96,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Ireland',
#   'CPV_division': '09',
#   'Avg_award_value': 71925000.0,
#   'Max_award_value': 280000000,
#   'Count_award_value': 4},
#  {'Year': 2012,
#   'Country': 'Slovenia',
#   'CPV_division': '09',
#   'Avg_award_value': 1668014.76,
#   'Max_award_value': 33000000,
#   'Count_award_value': 121},
#  {'Year': 2011,
#   'Country': 'Czechia',
#   'CPV_division': '09',
#   'Avg_award_value': 35674805.02,
#   'Max_award_value': 1016673424.16,
#   'Count_award_value': 269},
#  {'Year': 2014,
#   'Country': 'Estonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1585635.59,
#   'Max_award_value': 28239134,
#   'Count_award_value': 35},
#  {'Year': 2016,
#   'Country': 'Romania',
#   'CPV_division': '09',
#   'Avg_award_value': 1963987.14,
#   'Max_award_value': 197203884.91,
#   'Count_award_value': 330},
#  {'Year': 2014,
#   'Country': 'Germany',
#   'CPV_division': '09',
#   'Avg_award_value': 1269841.97,
#   'Max_award_value': 185000000,
#   'Count_award_value': 672},
#  {'Year': 2013,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 370382.0,
#   'Max_award_value': 550000,
#   'Count_award_value': 2},
#  {'Year': 2017,
#   'Country': 'Austria',
#   'CPV_division': '09',
#   'Avg_award_value': 1701620.36,
#   'Max_award_value': 13081447.4,
#   'Count_award_value': 17},
#  {'Year': 2016,
#   'Country': 'Spain',
#   'CPV_division': '03',
#   'Avg_award_value': 986495.27,
#   'Max_award_value': 23141290,
#   'Count_award_value': 46},
#  {'Year': 2012,
#   'Country': 'Cyprus',
#   'CPV_division': '03',
#   'Avg_award_value': 63181.45,
#   'Max_award_value': 214329.9,
#   'Count_award_value': 7},
#  {'Year': 2011,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 1247254.98,
#   'Max_award_value': 4225648.03,
#   'Count_award_value': 11},
#  {'Year': 2012,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 2780852.0,
#   'Max_award_value': 2780852,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'North Macedonia',
#   'CPV_division': '09',
#   'Avg_award_value': 336798.63,
#   'Max_award_value': 6682110,
#   'Count_award_value': 87},
#  {'Year': 2009,
#   'Country': 'Italy',
#   'CPV_division': '03',
#   'Avg_award_value': 650367.87,
#   'Max_award_value': 790583.6,
#   'Count_award_value': 3},
#  {'Year': 2015,
#   'Country': 'Bulgaria',
#   'CPV_division': '03',
#   'Avg_award_value': 81774.28,
#   'Max_award_value': 1942938.95,
#   'Count_award_value': 44},
#  {'Year': 2014,
#   'Country': 'Belgium',
#   'CPV_division': '03',
#   'Avg_award_value': 195998.94,
#   'Max_award_value': 290000,
#   'Count_award_value': 5},
#  {'Year': 2011,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 207339.45,
#   'Max_award_value': 738244,
#   'Count_award_value': 13},
#  {'Year': 2018,
#   'Country': 'Norway',
#   'CPV_division': '03',
#   'Avg_award_value': 5923057.21,
#   'Max_award_value': 112601389.7,
#   'Count_award_value': 26},
#  {'Year': 2014,
#   'Country': 'Netherlands',
#   'CPV_division': '03',
#   'Avg_award_value': 253857.14,
#   'Max_award_value': 770000,
#   'Count_award_value': 14},
#  {'Year': 2017,
#   'Country': 'Switzerland',
#   'CPV_division': '03',
#   'Avg_award_value': 1430758.45,
#   'Max_award_value': 6237387.64,
#   'Count_award_value': 5},
#  {'Year': 2014,
#   'Country': 'Norway',
#   'CPV_division': '09',
#   'Avg_award_value': 609442.36,
#   'Max_award_value': 2284211.82,
#   'Count_award_value': 13},
#  {'Year': 2014,
#   'Country': 'Italy',
#   'CPV_division': '09',
#   'Avg_award_value': 7885732.63,
#   'Max_award_value': 158272096,
#   'Count_award_value': 190},
#  {'Year': 2011,
#   'Country': 'Cyprus',
#   'CPV_division': '09',
#   'Avg_award_value': 53768952.0,
#   'Max_award_value': 212600000,
#   'Count_award_value': 4},
#  {'Year': 2014,
#   'Country': 'Greece',
#   'CPV_division': '09',
#   'Avg_award_value': 185543.82,
#   'Max_award_value': 14000000,
#   'Count_award_value': 435},
#  {'Year': 2015,
#   'Country': 'Bulgaria',
#   'CPV_division': '09',
#   'Avg_award_value': 646743.8,
#   'Max_award_value': 32856120.26,
#   'Count_award_value': 304},
#  {'Year': 2015,
#   'Country': 'Portugal',
#   'CPV_division': '09',
#   'Avg_award_value': 1312714.42,
#   'Max_award_value': 24075627.7,
#   'Count_award_value': 60},
#  {'Year': 2011,
#   'Country': 'Netherlands',
#   'CPV_division': '09',
#   'Avg_award_value': 4065915.96,
#   'Max_award_value': 19750000,
#   'Count_award_value': 24}]

# %%
query_0 = {
    '$match': {
        'AWARD_VALUE_EURO': {'$exists': True},
        'CPV': {'$gte': 10000000}
    }
}

query_1 = {
    '$project': {
        '_id': 0,
        'cpv_division': {'$substr': ['$CPV', 0, 2]},
        'award_values': '$AWARD_VALUE_EURO',
        'year': '$YEAR',
        'country_code': '$ISO_COUNTRY_CODE'
    }
}

query_2 = {
    '$group': {
        '_id': {'Year': '$year', 'Country_code': '$country_code', 'CPV_division': '$cpv_division'},
        'Count_award_value': {'$sum': 1},
        'Avg_award_value': {'$avg': '$award_values'},
        'Max_award_value': {'$max': '$award_values'}
    },
}

query_3 = {
    '$lookup': {
            'from': 'iso_codes',
            'localField': '_id.Country_code',   
            'foreignField': 'alpha-2',  
            'as': 'COUNTRY'
    }
}

query_4 = {
    '$project': {
        '_id': 0,
        'Year': '$_id.Year',
        'Country': {'$arrayElemAt': ['$COUNTRY.name', 0]}, 
        'CPV_division': '$_id.CPV_division',
        'Avg_award_value': {'$round': ['$Avg_award_value', 2]},
        'Max_award_value': {'$round': ['$Max_award_value', 2]},
        'Count_award_value': '$Count_award_value' 
    }
}

pipeline = [query_0, query_1, query_2, query_3, query_4]

r11_2 = col_eu.aggregate(pipeline)

result11_2 = list(r11_2)
result11_2
# Out:
# [{'Year': 2010,
#   'Country': 'Belgium',
#   'CPV_division': '43',
#   'Avg_award_value': 293236.5,
#   'Max_award_value': 644000,
#   'Count_award_value': 4},
#  {'Year': 2012,
#   'Country': 'Luxembourg',
#   'CPV_division': '50',
#   'Avg_award_value': 232136.04,
#   'Max_award_value': 400000,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Czechia',
#   'CPV_division': '34',
#   'Avg_award_value': 2968788.26,
#   'Max_award_value': 200465904,
#   'Count_award_value': 233},
#  {'Year': 2016,
#   'Country': 'Germany',
#   'CPV_division': '65',
#   'Avg_award_value': 1623537.19,
#   'Max_award_value': 123552517,
#   'Count_award_value': 155},
#  {'Year': 2014,
#   'Country': 'Hungary',
#   'CPV_division': '72',
#   'Avg_award_value': 649908.07,
#   'Max_award_value': 10780344.01,
#   'Count_award_value': 136},
#  {'Year': 2010,
#   'Country': 'Denmark',
#   'CPV_division': '44',
#   'Avg_award_value': 914114.05,
#   'Max_award_value': 2454822.55,
#   'Count_award_value': 5},
#  {'Year': 2014,
#   'Country': 'Finland',
#   'CPV_division': '15',
#   'Avg_award_value': 390000.0,
#   'Max_award_value': 390000,
#   'Count_award_value': 1},
#  {'Year': 2011,
#   'Country': 'Malta',
#   'CPV_division': '72',
#   'Avg_award_value': 475531.11,
#   'Max_award_value': 749898.3,
#   'Count_award_value': 2},
#  {'Year': 2010,
#   'Country': 'Austria',
#   'CPV_division': '76',
#   'Avg_award_value': 968500.0,
#   'Max_award_value': 1400000,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Cyprus',
#   'CPV_division': '37',
#   'Avg_award_value': 43787.03,
#   'Max_award_value': 106185.1,
#   'Count_award_value': 3},
#  {'Year': 2013,
#   'Country': 'Malta',
#   'CPV_division': '50',
#   'Avg_award_value': 186971.4,
#   'Max_award_value': 186971.4,
#   'Count_award_value': 1},
#  {'Year': 2010,
#   'Country': 'Cyprus',
#   'CPV_division': '66',
#   'Avg_award_value': 528830.75,
#   'Max_award_value': 620924,
#   'Count_award_value': 4},
#  {'Year': 2012,
#   'Country': 'Sweden',
#   'CPV_division': '65',
#   'Avg_award_value': 1378660.63,
#   'Max_award_value': 1895658.37,
#   'Count_award_value': 2},
#  {'Year': 2017,
#   'Country': 'Malta',
#   'CPV_division': '76',
#   'Avg_award_value': 498000.0,
#   'Max_award_value': 498000,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Greece',
#   'CPV_division': '16',
#   'Avg_award_value': 87748.75,
#   'Max_award_value': 165000,
#   'Count_award_value': 4},
#  {'Year': 2009,
#   'Country': 'Norway',
#   'CPV_division': '76',
#   'Avg_award_value': 7103737.48,
#   'Max_award_value': 7103737.48,
#   'Count_award_value': 1},
#  {'Year': 2013,
#   'Country': 'Slovakia',
#   'CPV_division': '65',
#   'Avg_award_value': 2096554.5,
#   'Max_award_value': 2153419,
#   'Count_award_value': 8},
#  {'Year': 2012,
#   'Country': 'Spain',
#   'CPV_division': '33',
#   'Avg_award_value': 399808.85,
#   'Max_award_value': 66969360,
#   'Count_award_value': 4591},
#  {'Year': 2018,
#   'Country': 'Norway',
#   'CPV_division': '72',
#   'Avg_award_value': 5708228.36,
#   'Max_award_value': 144000000,
#   'Count_award_value': 185},
#  {'Year': 2018,
#   'Country': 'Austria',
#   'CPV_division': '66',
#   'Avg_award_value': 2153828.93,
#   'Max_award_value': 23800000,
#   'Count_award_value': 22},
#  {'Year': 2015,
#   'Country': 'Germany',
#   'CPV_division': '45',
#   'Avg_award_value': 1053411.52,
#   'Max_award_value': 144798889.27,
#   'Count_award_value': 6203},
#  {'Year': 2015,
#   'Country': 'Norway',
#   'CPV_division': '48',
#   'Avg_award_value': 763748.45,
#   'Max_award_value': 4022526.15,
#   'Count_award_value': 24},
#  {'Year': 2012,
#   'Country': 'Latvia',
#   'CPV_division': '33',
#   'Avg_award_value': 155300.83,
#   'Max_award_value': 159000000,
#   'Count_award_value': 3144},
#  {'Year': 2014,
#   'Country': 'Norway',
#   'CPV_division': '98',
#   'Avg_award_value': 4054718.18,
#   'Max_award_value': 9575792.4,
#   'Count_award_value': 5},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '71',
#   'Avg_award_value': 1970136.64,
#   'Max_award_value': 97300000,
#   'Count_award_value': 293},
#  {'Year': 2009,
#   'Country': 'Norway',
#   'CPV_division': '85',
#   'Avg_award_value': 11637500.6,
#   'Max_award_value': 33322639.53,
#   'Count_award_value': 3},
#  {'Year': 2009,
#   'Country': 'Liechtenstein',
#   'CPV_division': '39',
#   'Avg_award_value': 110640.4,
#   'Max_award_value': 312279.97,
#   'Count_award_value': 5},
#  {'Year': 2011,
#   'Country': 'Finland',
#   'CPV_division': '39',
#   'Avg_award_value': 284764.82,
#   'Max_award_value': 1412364,
#   'Count_award_value': 28},
#  {'Year': 2012,
#   'Country': 'Latvia',
#   'CPV_division': '73',
#   'Avg_award_value': 83240.94,
#   'Max_award_value': 430230.89,
#   'Count_award_value': 306},
#  {'Year': 2014,
#   'Country': 'Croatia',
#   'CPV_division': '14',
#   'Avg_award_value': 878460.98,
#   'Max_award_value': 2238715.55,
#   'Count_award_value': 7},
#  {'Year': 2010,
#   'Country': 'Malta',
#   'CPV_division': '35',
#   'Avg_award_value': 91829.57,
#   'Max_award_value': 189762.71,
#   'Count_award_value': 3},
#  {'Year': 2016,
#   'Country': 'Latvia',
#   'CPV_division': '98',
#   'Avg_award_value': 153799.5,
#   'Max_award_value': 167599,
#   'Count_award_value': 2},
#  {'Year': 2013,
#   'Country': 'Czechia',
#   'CPV_division': '55',
#   'Avg_award_value': 392379.0,
#   'Max_award_value': 7883493.15,
#   'Count_award_value': 41},
#  {'Year': 2009,
#   'Country': 'Greece',
#   'CPV_division': '80',
#   'Avg_award_value': 344593.1,
#   'Max_award_value': 927612,
#   'Count_award_value': 43},
#  {'Year': 2012,
#   'Country': 'Norway',
#   'CPV_division': '90',
#   'Avg_award_value': 820942.59,
#   'Max_award_value': 9364423.22,
#   'Count_award_value': 57},
#  {'Year': 2010,
#   'Country': 'Sweden',
#   'CPV_division': '35',
#   'Avg_award_value': 143361.86,
#   'Max_award_value': 166451.72,
#   'Count_award_value': 2},
#  {'Year': 2010,
#   'Country': 'Austria',
#   'CPV_division': '43',
#   'Avg_award_value': 278800.0,
#   'Max_award_value': 401600,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '18',
#   'Avg_award_value': 247568.99,
#   'Max_award_value': 6851020,
#   'Count_award_value': 154},
#  {'Year': 2011,
#   'Country': 'Cyprus',
#   'CPV_division': '60',
#   'Avg_award_value': 41158.08,
#   'Max_award_value': 394800,
#   'Count_award_value': 37},
#  {'Year': 2011,
#   'Country': 'Czechia',
#   'CPV_division': '15',
#   'Avg_award_value': 314158.48,
#   'Max_award_value': 822211.55,
#   'Count_award_value': 19},
#  {'Year': 2015,
#   'Country': 'Romania',
#   'CPV_division': '50',
#   'Avg_award_value': 987905.36,
#   'Max_award_value': 72544073.32,
#   'Count_award_value': 599},
#  {'Year': 2018,
#   'Country': 'Denmark',
#   'CPV_division': '90',
#   'Avg_award_value': 1327535.42,
#   'Max_award_value': 49353305.97,
#   'Count_award_value': 644},
#  {'Year': 2013,
#   'Country': 'Switzerland',
#   'CPV_division': '39',
#   'Avg_award_value': 631710.02,
#   'Max_award_value': 5488847.37,
#   'Count_award_value': 31},
#  {'Year': 2014,
#   'CPV_division': '33',
#   'Avg_award_value': 2842889.97,
#   'Max_award_value': 94667047.09,
#   'Count_award_value': 190},
#  {'Year': 2016,
#   'Country': 'Belgium',
#   'CPV_division': '63',
#   'Avg_award_value': 874479.75,
#   'Max_award_value': 3966942,
#   'Count_award_value': 13},
#  {'Year': 2013,
#   'Country': 'Slovakia',
#   'CPV_division': '71',
#   'Avg_award_value': 907970.26,
#   'Max_award_value': 8790242,
#   'Count_award_value': 70},
#  {'Year': 2014,
#   'Country': 'Denmark',
#   'CPV_division': '31',
#   'Avg_award_value': 688629.11,
#   'Max_award_value': 4287841.39,
#   'Count_award_value': 28},
#  {'Year': 2015,
#   'Country': 'Denmark',
#   'CPV_division': '98',
#   'Avg_award_value': 7304353.5,
#   'Max_award_value': 41527384.13,
#   'Count_award_value': 9},
#  {'Year': 2014,
#   'Country': 'Norway',
#   'CPV_division': '45',
#   'Avg_award_value': 7598280.49,
#   'Max_award_value': 190979419.23,
#   'Count_award_value': 144},
#  {'Year': 2016,
#   'Country': 'Denmark',
#   'CPV_division': '71',
#   'Avg_award_value': 1609872.54,
#   'Max_award_value': 12066445.9,
#   'Count_award_value': 208},
#  {'Year': 2017,
#   'Country': 'Cyprus',
#   'CPV_division': '75',
#   'Avg_award_value': 10740.0,
#   'Max_award_value': 12000,
#   'Count_award_value': 9},
#  {'Year': 2015,
#   'Country': 'Ireland',
#   'CPV_division': '85',
#   'Avg_award_value': 910486.25,
#   'Max_award_value': 5000000,
#   'Count_award_value': 8},
#  {'Year': 2018,
#   'Country': 'Hungary',
#   'CPV_division': '41',
#   'Avg_award_value': 182513.54,
#   'Max_award_value': 317979.41,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Finland',
#   'CPV_division': '30',
#   'Avg_award_value': 460519.83,
#   'Max_award_value': 800000,
#   'Count_award_value': 6},
#  {'Year': 2012,
#   'Country': 'Portugal',
#   'CPV_division': '35',
#   'Avg_award_value': 198549.22,
#   'Max_award_value': 487810,
#   'Count_award_value': 9},
#  {'Year': 2015,
#   'Country': 'Ireland',
#   'CPV_division': '34',
#   'Avg_award_value': 2678637.99,
#   'Max_award_value': 28500000,
#   'Count_award_value': 25},
#  {'Year': 2017,
#   'Country': 'Cyprus',
#   'CPV_division': '92',
#   'Avg_award_value': 68000.0,
#   'Max_award_value': 68000,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Iceland',
#   'CPV_division': '34',
#   'Avg_award_value': 2570887.32,
#   'Max_award_value': 82205792,
#   'Count_award_value': 34},
#  {'Year': 2015,
#   'Country': 'Finland',
#   'CPV_division': '44',
#   'Avg_award_value': 1460149.5,
#   'Max_award_value': 7918025,
#   'Count_award_value': 8},
#  {'Year': 2016,
#   'Country': 'Malta',
#   'CPV_division': '32',
#   'Avg_award_value': 53172.27,
#   'Max_award_value': 311313,
#   'Count_award_value': 8},
#  {'Year': 2013,
#   'Country': 'Finland',
#   'CPV_division': '70',
#   'Avg_award_value': 217951.59,
#   'Max_award_value': 1310160,
#   'Count_award_value': 44},
#  {'Year': 2014,
#   'Country': 'Lithuania',
#   'CPV_division': '60',
#   'Avg_award_value': 215446.25,
#   'Max_award_value': 981981.91,
#   'Count_award_value': 12},
#  {'Year': 2017,
#   'Country': 'Latvia',
#   'CPV_division': '19',
#   'Avg_award_value': 425540.08,
#   'Max_award_value': 425540.08,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'France',
#   'CPV_division': '90',
#   'Avg_award_value': 760503.27,
#   'Max_award_value': 148585264,
#   'Count_award_value': 3524},
#  {'Year': 2018,
#   'Country': 'Italy',
#   'CPV_division': '16',
#   'Avg_award_value': 539000.0,
#   'Max_award_value': 539000,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Belgium',
#   'CPV_division': '39',
#   'Avg_award_value': 676479.15,
#   'Max_award_value': 19050000,
#   'Count_award_value': 178},
#  {'Year': 2018,
#   'Country': 'Spain',
#   'CPV_division': '65',
#   'Avg_award_value': 5605993.91,
#   'Max_award_value': 54594002.28,
#   'Count_award_value': 92},
#  {'Year': 2009,
#   'Country': 'Estonia',
#   'CPV_division': '60',
#   'Avg_award_value': 2200145.18,
#   'Max_award_value': 5072028.43,
#   'Count_award_value': 11},
#  {'Year': 2017,
#   'Country': 'North Macedonia',
#   'CPV_division': '77',
#   'Avg_award_value': 75259.33,
#   'Max_award_value': 412753.02,
#   'Count_award_value': 18},
#  {'Year': 2009,
#   'Country': 'Estonia',
#   'CPV_division': '37',
#   'Avg_award_value': 960951.61,
#   'Max_award_value': 1019953.22,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Spain',
#   'CPV_division': '31',
#   'Avg_award_value': 1388083.25,
#   'Max_award_value': 62472192,
#   'Count_award_value': 164},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '18',
#   'Avg_award_value': 180517.26,
#   'Max_award_value': 3674528.97,
#   'Count_award_value': 255},
#  {'Year': 2010,
#   'Country': 'Bulgaria',
#   'CPV_division': '42',
#   'Avg_award_value': 453248.88,
#   'Max_award_value': 2099038.76,
#   'Count_award_value': 24},
#  {'Year': 2011,
#   'Country': 'Portugal',
#   'CPV_division': '71',
#   'Avg_award_value': 557244.33,
#   'Max_award_value': 3852395,
#   'Count_award_value': 75},
#  {'Year': 2015,
#   'Country': 'Ireland',
#   'CPV_division': '48',
#   'Avg_award_value': 2287969.74,
#   'Max_award_value': 28455284.55,
#   'Count_award_value': 18},
#  {'Year': 2010,
#   'Country': 'France',
#   'CPV_division': '76',
#   'Avg_award_value': 89781.0,
#   'Max_award_value': 89781,
#   'Count_award_value': 1},
#  {'Year': 2011,
#   'Country': 'Norway',
#   'CPV_division': '14',
#   'Avg_award_value': 859378.45,
#   'Max_award_value': 988395.31,
#   'Count_award_value': 2},
#  {'Year': 2012,
#   'Country': 'Estonia',
#   'CPV_division': '50',
#   'Avg_award_value': 412640.79,
#   'Max_award_value': 3200000,
#   'Count_award_value': 30},
#  {'Year': 2017,
#   'Country': 'Finland',
#   'CPV_division': '79',
#   'Avg_award_value': 1450118.01,
#   'Max_award_value': 40000000,
#   'Count_award_value': 337},
#  {'Year': 2011,
#   'Country': 'Sweden',
#   'CPV_division': '39',
#   'Avg_award_value': 1143434.98,
#   'Max_award_value': 2900728.7,
#   'Count_award_value': 5},
#  {'Year': 2013,
#   'Country': 'Italy',
#   'CPV_division': '51',
#   'Avg_award_value': 2210901.15,
#   'Max_award_value': 50129640,
#   'Count_award_value': 31},
#  {'Year': 2017,
#   'Country': 'France',
#   'CPV_division': '43',
#   'Avg_award_value': 366264.28,
#   'Max_award_value': 24200000,
#   'Count_award_value': 324},
#  {'Year': 2015,
#   'Country': 'Switzerland',
#   'CPV_division': '33',
#   'Avg_award_value': 538897.68,
#   'Max_award_value': 1734487.69,
#   'Count_award_value': 40},
#  {'Year': 2018,
#   'CPV_division': '55',
#   'Avg_award_value': 10822712.2,
#   'Max_award_value': 259752025.84,
#   'Count_award_value': 239},
#  {'Year': 2018,
#   'Country': 'Estonia',
#   'CPV_division': '43',
#   'Avg_award_value': 1023773.62,
#   'Max_award_value': 2499000,
#   'Count_award_value': 4},
#  {'Year': 2018,
#   'Country': 'Finland',
#   'CPV_division': '18',
#   'Avg_award_value': 715876.6,
#   'Max_award_value': 4496960,
#   'Count_award_value': 30},
#  {'Year': 2017,
#   'Country': 'Norway',
#   'CPV_division': '79',
#   'Avg_award_value': 1257817.76,
#   'Max_award_value': 16145351.22,
#   'Count_award_value': 231},
#  {'Year': 2018,
#   'Country': 'Sweden',
#   'CPV_division': '18',
#   'Avg_award_value': 316293.68,
#   'Max_award_value': 8320159.71,
#   'Count_award_value': 106},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '42',
#   'Avg_award_value': 704303.86,
#   'Max_award_value': 69114531.68,
#   'Count_award_value': 769},
#  {'Year': 2017,
#   'Country': 'Italy',
#   'CPV_division': '19',
#   'Avg_award_value': 820093.16,
#   'Max_award_value': 10350000,
#   'Count_award_value': 76},
#  {'Year': 2011,
#   'Country': 'Sweden',
#   'CPV_division': '65',
#   'Avg_award_value': 10966275.96,
#   'Max_award_value': 32115882.97,
#   'Count_award_value': 3},
#  {'Year': 2014,
#   'Country': 'Italy',
#   'CPV_division': '90',
#   'Avg_award_value': 2301385.08,
#   'Max_award_value': 390535520,
#   'Count_award_value': 852},
#  {'Year': 2018,
#   'Country': 'Poland',
#   'CPV_division': '41',
#   'Avg_award_value': 1059952.68,
#   'Max_award_value': 5432647.16,
#   'Count_award_value': 13},
#  {'Year': 2018,
#   'Country': 'Sweden',
#   'CPV_division': '73',
#   'Avg_award_value': 165950.82,
#   'Max_award_value': 873616.77,
#   'Count_award_value': 21},
#  {'Year': 2012,
#   'CPV_division': '50',
#   'Avg_award_value': 5539845.81,
#   'Max_award_value': 231233119.98,
#   'Count_award_value': 280},
#  {'Year': 2014,
#   'CPV_division': '75',
#   'Avg_award_value': 7270285.38,
#   'Max_award_value': 66987545.28,
#   'Count_award_value': 48},
#  {'Year': 2010,
#   'Country': 'Estonia',
#   'CPV_division': '64',
#   'Avg_award_value': 590703.73,
#   'Max_award_value': 1429084.91,
#   'Count_award_value': 5},
#  {'Year': 2013,
#   'Country': 'Croatia',
#   'CPV_division': '72',
#   'Avg_award_value': 609472.68,
#   'Max_award_value': 1297650.62,
#   'Count_award_value': 13},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '33',
#   'Avg_award_value': 42036.53,
#   'Max_award_value': 22944002.29,
#   'Count_award_value': 72598},
#  {'Year': 2014,
#   'Country': 'France',
#   'CPV_division': '50',
#   'Avg_award_value': 1151612.31,
#   'Max_award_value': 354788000,
#   'Count_award_value': 2353},
#  {'Year': 2016,
#   'Country': 'Lithuania',
#   'CPV_division': '85',
#   'Avg_award_value': 300261.02,
#   'Max_award_value': 1039669.42,
#   'Count_award_value': 15},
#  {'Year': 2015,
#   'Country': 'Luxembourg',
#   'CPV_division': '42',
#   'Avg_award_value': 216987.33,
#   'Max_award_value': 269162,
#   'Count_award_value': 3},
#  {'Year': 2011,
#   'Country': 'North Macedonia',
#   'CPV_division': '98',
#   'Avg_award_value': 3559451.57,
#   'Max_award_value': 3559451.57,
#   'Count_award_value': 1},
#  {'Year': 2013,
#   'Country': 'Slovenia',
#   'CPV_division': '44',
#   'Avg_award_value': 884324.1,
#   'Max_award_value': 9379079,
#   'Count_award_value': 53},
#  {'Year': 2015,
#   'Country': 'Estonia',
#   'CPV_division': '18',
#   'Avg_award_value': 148323.5,
#   'Max_award_value': 182710,
#   'Count_award_value': 2},
#  {'Year': 2018,
#   'Country': 'Denmark',
#   'CPV_division': '39',
#   'Avg_award_value': 4985156.41,
#   'Max_award_value': 24141631.38,
#   'Count_award_value': 51},
#  {'Year': 2012,
#   'Country': 'Latvia',
#   'CPV_division': '51',
#   'Avg_award_value': 149616.14,
#   'Max_award_value': 286820.59,
#   'Count_award_value': 3},
#  {'Year': 2016,
#   'CPV_division': '42',
#   'Avg_award_value': 589440506.99,
#   'Max_award_value': 12399426870.94,
#   'Count_award_value': 106},
#  {'Year': 2015,
#   'Country': 'Cyprus',
#   'CPV_division': '64',
#   'Avg_award_value': 396999.0,
#   'Max_award_value': 396999,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'Spain',
#   'CPV_division': '85',
#   'Avg_award_value': 31782493.0,
#   'Max_award_value': 2127651710,
#   'Count_award_value': 129},
#  {'Year': 2009,
#   'Country': 'Sweden',
#   'CPV_division': '48',
#   'Avg_award_value': 351565.14,
#   'Max_award_value': 932282.4,
#   'Count_award_value': 9},
#  {'Year': 2011,
#   'Country': 'Switzerland',
#   'CPV_division': '71',
#   'Avg_award_value': 1195898.05,
#   'Max_award_value': 20225262.05,
#   'Count_award_value': 248},
#  {'Year': 2016,
#   'Country': 'Malta',
#   'CPV_division': '90',
#   'Avg_award_value': 182329.44,
#   'Max_award_value': 1534455,
#   'Count_award_value': 30},
#  {'Year': 2011,
#   'Country': 'Poland',
#   'CPV_division': '64',
#   'Avg_award_value': 326026.09,
#   'Max_award_value': 31268411.4,
#   'Count_award_value': 755},
#  {'Year': 2011,
#   'Country': 'Germany',
#   'CPV_division': '44',
#   'Avg_award_value': 562228.67,
#   'Max_award_value': 7559510.5,
#   'Count_award_value': 271},
#  {'Year': 2013,
#   'Country': 'Spain',
#   'CPV_division': '55',
#   'Avg_award_value': 1230783.24,
#   'Max_award_value': 8951250,
#   'Count_award_value': 52},
#  {'Year': 2009,
#   'Country': 'France',
#   'CPV_division': '34',
#   'Avg_award_value': 342300.97,
#   'Max_award_value': 117439456,
#   'Count_award_value': 2771},
#  {'Year': 2013,
#   'Country': 'Luxembourg',
#   'CPV_division': '18',
#   'Avg_award_value': 36146.0,
#   'Max_award_value': 94800,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Hungary',
#   'CPV_division': '45',
#   'Avg_award_value': 4370566.77,
#   'Max_award_value': 178871897.48,
#   'Count_award_value': 535},
#  {'Year': 2012,
#   'Country': 'Poland',
#   'CPV_division': '55',
#   'Avg_award_value': 307435.69,
#   'Max_award_value': 34963653.31,
#   'Count_award_value': 580},
#  {'Year': 2012,
#   'Country': 'Belgium',
#   'CPV_division': '60',
#   'Avg_award_value': 5990611.09,
#   'Max_award_value': 45000000,
#   'Count_award_value': 50},
#  {'Year': 2013,
#   'Country': 'Italy',
#   'CPV_division': '43',
#   'Avg_award_value': 600571.61,
#   'Max_award_value': 1527500,
#   'Count_award_value': 12},
#  {'Year': 2013,
#   'Country': 'Norway',
#   'CPV_division': '71',
#   'Avg_award_value': 1187845.77,
#   'Max_award_value': 12297129.39,
#   'Count_award_value': 33},
#  {'Year': 2015,
#   'Country': 'Greece',
#   'CPV_division': '79',
#   'Avg_award_value': 769788.54,
#   'Max_award_value': 4000000,
#   'Count_award_value': 68},
#  {'Year': 2018,
#   'Country': 'Belgium',
#   'CPV_division': '75',
#   'Avg_award_value': 1960696.91,
#   'Max_award_value': 14000000,
#   'Count_award_value': 11},
#  {'Year': 2010,
#   'Country': 'Spain',
#   'CPV_division': '33',
#   'Avg_award_value': 295348.71,
#   'Max_award_value': 132191216,
#   'Count_award_value': 6178},
#  {'Year': 2018,
#   'Country': 'Switzerland',
#   'CPV_division': '79',
#   'Avg_award_value': 4638158.33,
#   'Max_award_value': 104951495.68,
#   'Count_award_value': 120},
#  {'Year': 2011,
#   'Country': 'Iceland',
#   'CPV_division': '55',
#   'Avg_award_value': 172189.32,
#   'Max_award_value': 297410.48,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'Country': 'Netherlands',
#   'CPV_division': '39',
#   'Avg_award_value': 834684.64,
#   'Max_award_value': 10500000,
#   'Count_award_value': 53},
#  {'Year': 2016,
#   'Country': 'Germany',
#   'CPV_division': '39',
#   'Avg_award_value': 475253.33,
#   'Max_award_value': 43320800,
#   'Count_award_value': 427},
#  {'Year': 2013,
#   'Country': 'Lithuania',
#   'CPV_division': '79',
#   'Avg_award_value': 346501.39,
#   'Max_award_value': 8818564.79,
#   'Count_award_value': 172},
#  {'Year': 2016,
#   'Country': 'Croatia',
#   'CPV_division': '75',
#   'Avg_award_value': 23723.38,
#   'Max_award_value': 728019.36,
#   'Count_award_value': 84},
#  {'Year': 2017,
#   'Country': 'Estonia',
#   'CPV_division': '15',
#   'Avg_award_value': 320648.84,
#   'Max_award_value': 4000000,
#   'Count_award_value': 73},
#  {'Year': 2017,
#   'Country': 'Estonia',
#   'CPV_division': '32',
#   'Avg_award_value': 405212.07,
#   'Max_award_value': 4054061,
#   'Count_award_value': 24},
#  {'Year': 2011,
#   'Country': 'Ireland',
#   'CPV_division': '92',
#   'Avg_award_value': 523964.1,
#   'Max_award_value': 523964.1,
#   'Count_award_value': 1},
#  {'Year': 2011,
#   'Country': 'Malta',
#   'CPV_division': '79',
#   'Avg_award_value': 291181.18,
#   'Max_award_value': 848480,
#   'Count_award_value': 7},
#  {'Year': 2012,
#   'Country': 'Luxembourg',
#   'CPV_division': '73',
#   'Avg_award_value': 5092147.7,
#   'Max_award_value': 10000000,
#   'Count_award_value': 10},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '37',
#   'Avg_award_value': 284000.33,
#   'Max_award_value': 1500000,
#   'Count_award_value': 45},
#  {'Year': 2017,
#   'Country': 'Germany',
#   'CPV_division': '73',
#   'Avg_award_value': 1118371.51,
#   'Max_award_value': 28427035.66,
#   'Count_award_value': 176},
#  {'Year': 2014,
#   'Country': 'Hungary',
#   'CPV_division': '34',
#   'Avg_award_value': 667966.67,
#   'Max_award_value': 90462456,
#   'Count_award_value': 515},
#  {'Year': 2011,
#   'Country': 'Luxembourg',
#   'CPV_division': '71',
#   'Avg_award_value': 1002590.28,
#   'Max_award_value': 4000000,
#   'Count_award_value': 16},
#  {'Year': 2013,
#   'Country': 'Malta',
#   'CPV_division': '41',
#   'Avg_award_value': 231650.0,
#   'Max_award_value': 231650,
#   'Count_award_value': 1},
#  {'Year': 2016,
#   'Country': 'Germany',
#   'CPV_division': '77',
#   'Avg_award_value': 97808.17,
#   'Max_award_value': 3193649.92,
#   'Count_award_value': 323},
#  {'Year': 2017,
#   'Country': 'Sweden',
#   'CPV_division': '48',
#   'Avg_award_value': 1606199.89,
#   'Max_award_value': 52365320.58,
#   'Count_award_value': 98},
#  {'Year': 2009,
#   'Country': 'Latvia',
#   'CPV_division': '92',
#   'Avg_award_value': 710747.2,
#   'Max_award_value': 1079287.23,
#   'Count_award_value': 2},
#  {'Year': 2013,
#   'Country': 'Romania',
#   'CPV_division': '77',
#   'Avg_award_value': 249211.05,
#   'Max_award_value': 87613038.24,
#   'Count_award_value': 555},
#  {'Year': 2010,
#   'Country': 'Luxembourg',
#   'CPV_division': '30',
#   'Avg_award_value': 809520.73,
#   'Max_award_value': 4062000,
#   'Count_award_value': 7},
#  {'Year': 2015,
#   'Country': 'Greece',
#   'CPV_division': '42',
#   'Avg_award_value': 2595548.99,
#   'Max_award_value': 32338036,
#   'Count_award_value': 33},
#  {'Year': 2015,
#   'Country': 'Hungary',
#   'CPV_division': '35',
#   'Avg_award_value': 2276241.34,
#   'Max_award_value': 34985739,
#   'Count_award_value': 20},
#  {'Year': 2012,
#   'Country': 'Denmark',
#   'CPV_division': '37',
#   'Avg_award_value': 246087.58,
#   'Max_award_value': 857125.49,
#   'Count_award_value': 17},
#  {'Year': 2009,
#   'Country': 'Austria',
#   'CPV_division': '38',
#   'Avg_award_value': 597725.74,
#   'Max_award_value': 3513830,
#   'Count_award_value': 17},
#  {'Year': 2011,
#   'Country': 'Malta',
#   'CPV_division': '15',
#   'Avg_award_value': 42008.7,
#   'Max_award_value': 42008.7,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Norway',
#   'CPV_division': '98',
#   'Avg_award_value': 833556.81,
#   'Max_award_value': 833556.81,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'Slovakia',
#   'CPV_division': '45',
#   'Avg_award_value': 25315187.47,
#   'Max_award_value': 3310582020,
#   'Count_award_value': 251},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '14',
#   'Avg_award_value': 1544500.12,
#   'Max_award_value': 2000000,
#   'Count_award_value': 16},
#  {'Year': 2014,
#   'Country': 'Belgium',
#   'CPV_division': '32',
#   'Avg_award_value': 1546426.92,
#   'Max_award_value': 16172885,
#   'Count_award_value': 46},
#  {'Year': 2010,
#   'Country': 'Sweden',
#   'CPV_division': '92',
#   'Avg_award_value': 997347.26,
#   'Max_award_value': 997347.26,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Slovenia',
#   'CPV_division': '19',
#   'Avg_award_value': 198563.96,
#   'Max_award_value': 763350,
#   'Count_award_value': 9},
#  {'Year': 2017,
#   'Country': 'Slovakia',
#   'CPV_division': '98',
#   'Avg_award_value': 323252.48,
#   'Max_award_value': 775000,
#   'Count_award_value': 6},
#  {'Year': 2017,
#   'Country': 'Czechia',
#   'CPV_division': '31',
#   'Avg_award_value': 1419126.41,
#   'Max_award_value': 30040445.14,
#   'Count_award_value': 110},
#  {'Year': 2012,
#   'Country': 'Austria',
#   'CPV_division': '55',
#   'Avg_award_value': 4209460.0,
#   'Max_award_value': 7440951,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '19',
#   'Avg_award_value': 219064.76,
#   'Max_award_value': 1920000,
#   'Count_award_value': 18},
#  {'Year': 2017,
#   'Country': 'North Macedonia',
#   'CPV_division': '72',
#   'Avg_award_value': 136519.56,
#   'Max_award_value': 324699.04,
#   'Count_award_value': 6},
#  {'Year': 2010,
#   'Country': 'Poland',
#   'CPV_division': '70',
#   'Avg_award_value': 494510.65,
#   'Max_award_value': 104760623.83,
#   'Count_award_value': 296},
#  {'Year': 2016,
#   'Country': 'Malta',
#   'CPV_division': '66',
#   'Avg_award_value': 222322.6,
#   'Max_award_value': 731968.56,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Hungary',
#   'CPV_division': '48',
#   'Avg_award_value': 3506651.23,
#   'Max_award_value': 35794824.07,
#   'Count_award_value': 37},
#  {'Year': 2009,
#   'Country': 'Finland',
#   'CPV_division': '65',
#   'Avg_award_value': 380000.0,
#   'Max_award_value': 500000,
#   'Count_award_value': 3},
#  {'Year': 2013,
#   'Country': 'Austria',
#   'CPV_division': '45',
#   'Avg_award_value': 1729484.0,
#   'Max_award_value': 99473632,
#   'Count_award_value': 561},
#  {'Year': 2011,
#   'Country': 'Denmark',
#   'CPV_division': '76',
#   'Avg_award_value': 5121653.56,
#   'Max_award_value': 5121653.56,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Norway',
#   'CPV_division': '22',
#   'Avg_award_value': 3270921.63,
#   'Max_award_value': 29183945.49,
#   'Count_award_value': 41},
#  {'Year': 2012,
#   'Country': 'Cyprus',
#   'CPV_division': '44',
#   'Avg_award_value': 223013.66,
#   'Max_award_value': 1011000,
#   'Count_award_value': 33},
#  {'Year': 2015,
#   'Country': 'Netherlands',
#   'CPV_division': '33',
#   'Avg_award_value': 3430654.39,
#   'Max_award_value': 9772818.18,
#   'Count_award_value': 9},
#  {'Year': 2016,
#   'Country': 'Romania',
#   'CPV_division': '24',
#   'Avg_award_value': 176845.05,
#   'Max_award_value': 7043944.3,
#   'Count_award_value': 352},
#  {'Year': 2014,
#   'Country': 'Poland',
#   'CPV_division': '14',
#   'Avg_award_value': 510544.36,
#   'Max_award_value': 13918457.09,
#   'Count_award_value': 97},
#  {'Year': 2015,
#   'Country': 'Sweden',
#   'CPV_division': '63',
#   'Avg_award_value': 270375.8,
#   'Max_award_value': 311765.65,
#   'Count_award_value': 5},
#  {'Year': 2012,
#   'Country': 'Cyprus',
#   'CPV_division': '80',
#   'Avg_award_value': 779428.33,
#   'Max_award_value': 1998500,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Bulgaria',
#   'CPV_division': '70',
#   'Avg_award_value': 476442.4,
#   'Max_award_value': 2300848.69,
#   'Count_award_value': 6},
#  {'Year': 2010,
#   'Country': 'Poland',
#   'CPV_division': '35',
#   'Avg_award_value': 252627.55,
#   'Max_award_value': 3337282.9,
#   'Count_award_value': 111},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '22',
#   'Avg_award_value': 1026041.33,
#   'Max_award_value': 7794147,
#   'Count_award_value': 55},
#  {'Year': 2015,
#   'Country': 'Slovenia',
#   'CPV_division': '22',
#   'Avg_award_value': 592371.01,
#   'Max_award_value': 4201463.8,
#   'Count_award_value': 10},
#  {'Year': 2015,
#   'Country': 'Belgium',
#   'CPV_division': '64',
#   'Avg_award_value': 4345178.06,
#   'Max_award_value': 17785447.13,
#   'Count_award_value': 19},
#  {'Year': 2016,
#   'Country': 'Bulgaria',
#   'CPV_division': '43',
#   'Avg_award_value': 249001.29,
#   'Max_award_value': 2490038.35,
#   'Count_award_value': 61},
#  {'Year': 2017,
#   'Country': 'Slovenia',
#   'CPV_division': '30',
#   'Avg_award_value': 123880.99,
#   'Max_award_value': 6796696.72,
#   'Count_award_value': 565},
#  {'Year': 2009,
#   'Country': 'Estonia',
#   'CPV_division': '64',
#   'Avg_award_value': 119842.92,
#   'Max_award_value': 605851.75,
#   'Count_award_value': 23},
#  {'Year': 2009,
#   'Country': 'Poland',
#   'CPV_division': '16',
#   'Avg_award_value': 414729.87,
#   'Max_award_value': 727724.37,
#   'Count_award_value': 3},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '41',
#   'Avg_award_value': 3543497.82,
#   'Max_award_value': 9861328,
#   'Count_award_value': 5},
#  {'Year': 2016,
#   'CPV_division': '18',
#   'Avg_award_value': 705469.04,
#   'Max_award_value': 20665711.45,
#   'Count_award_value': 120},
#  {'Year': 2017,
#   'Country': 'Hungary',
#   'CPV_division': '92',
#   'Avg_award_value': 2146157.75,
#   'Max_award_value': 6420935.01,
#   'Count_award_value': 7},
#  {'Year': 2011,
#   'Country': 'France',
#   'CPV_division': '72',
#   'Avg_award_value': 1578361.49,
#   'Max_award_value': 206831488,
#   'Count_award_value': 783},
#  {'Year': 2017,
#   'Country': 'Austria',
#   'CPV_division': '37',
#   'Avg_award_value': 356595.75,
#   'Max_award_value': 627505,
#   'Count_award_value': 7},
#  {'Year': 2012,
#   'Country': 'Portugal',
#   'CPV_division': '30',
#   'Avg_award_value': 273171.82,
#   'Max_award_value': 1051755.1,
#   'Count_award_value': 19},
#  {'Year': 2013,
#   'Country': 'Cyprus',
#   'CPV_division': '80',
#   'Avg_award_value': 207390.0,
#   'Max_award_value': 446800,
#   'Count_award_value': 10},
#  {'Year': 2010,
#   'CPV_division': '70',
#   'Avg_award_value': 4561031.94,
#   'Max_award_value': 42047468.06,
#   'Count_award_value': 62},
#  {'Year': 2014,
#   'Country': 'Greece',
#   'CPV_division': '22',
#   'Avg_award_value': 60643.22,
#   'Max_award_value': 390000,
#   'Count_award_value': 48},
#  {'Year': 2011,
#   'Country': 'Latvia',
#   'CPV_division': '72',
#   'Avg_award_value': 840068.15,
#   'Max_award_value': 5663315.87,
#   'Count_award_value': 108},
#  {'Year': 2015,
#   'Country': 'Poland',
#   'CPV_division': '35',
#   'Avg_award_value': 761178.16,
#   'Max_award_value': 38688414.71,
#   'Count_award_value': 419},
#  {'Year': 2011,
#   'Country': 'Ireland',
#   'CPV_division': '15',
#   'Avg_award_value': 1605555.56,
#   'Max_award_value': 5000000,
#   'Count_award_value': 9},
#  {'Year': 2010,
#   'Country': 'Portugal',
#   'CPV_division': '72',
#   'Avg_award_value': 1206397.11,
#   'Max_award_value': 28000000,
#   'Count_award_value': 39},
#  {'Year': 2010,
#   'Country': 'Poland',
#   'CPV_division': '45',
#   'Avg_award_value': 8559456.29,
#   'Max_award_value': 450581467.95,
#   'Count_award_value': 1443},
#  {'Year': 2015,
#   'Country': 'Germany',
#   'CPV_division': '72',
#   'Avg_award_value': 1048373.04,
#   'Max_award_value': 36676818.65,
#   'Count_award_value': 240},
#  {'Year': 2016,
#   'Country': 'Switzerland',
#   'CPV_division': '41',
#   'Avg_award_value': 384045.32,
#   'Max_award_value': 384045.32,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Cyprus',
#   'CPV_division': '76',
#   'Avg_award_value': 25000.0,
#   'Max_award_value': 25000,
#   'Count_award_value': 1},
#  {'Year': 2011,
#   'CPV_division': '85',
#   'Avg_award_value': 7114038.9,
#   'Max_award_value': 481633405.54,
#   'Count_award_value': 433},
#  {'Year': 2015,
#   'Country': 'Latvia',
#   'CPV_division': '30',
#   'Avg_award_value': 1950276.02,
#   'Max_award_value': 8000000,
#   'Count_award_value': 124},
#  {'Year': 2013,
#   'Country': 'Denmark',
#   'CPV_division': '45',
#   'Avg_award_value': 5632606.17,
#   'Max_award_value': 175650174.98,
#   'Count_award_value': 268},
#  {'Year': 2013,
#   'Country': 'Denmark',
#   'CPV_division': '80',
#   'Avg_award_value': 1427849.76,
#   'Max_award_value': 6704300.14,
#   'Count_award_value': 28},
#  {'Year': 2018,
#   'Country': 'Slovakia',
#   'CPV_division': '31',
#   'Avg_award_value': 653610.54,
#   'Max_award_value': 3835140.03,
#   'Count_award_value': 13},
#  {'Year': 2012,
#   'Country': 'Germany',
#   'CPV_division': '92',
#   'Avg_award_value': 837294.9,
#   'Max_award_value': 7022016,
#   'Count_award_value': 12},
#  {'Year': 2009,
#   'Country': 'Romania',
#   'CPV_division': '66',
#   'Avg_award_value': 4639375.89,
#   'Max_award_value': 187500000,
#   'Count_award_value': 89},
#  {'Year': 2018,
#   'Country': 'France',
#   'CPV_division': '50',
#   'Avg_award_value': 3445674757.43,
#   'Max_award_value': 999999999999,
#   'Count_award_value': 5231},
#  {'Year': 2015,
#   'Country': 'North Macedonia',
#   'CPV_division': '60',
#   'Avg_award_value': 30886.88,
#   'Max_award_value': 186395.29,
#   'Count_award_value': 93},
#  {'Year': 2010,
#   'Country': 'Bulgaria',
#   'CPV_division': '18',
#   'Avg_award_value': 281194.7,
#   'Max_award_value': 751710,
#   'Count_award_value': 9},
#  {'Year': 2013,
#   'Country': 'Denmark',
#   'CPV_division': '71',
#   'Avg_award_value': 940404.91,
#   'Max_award_value': 23904985.59,
#   'Count_award_value': 111},
#  {'Year': 2012,
#   'Country': 'Belgium',
#   'CPV_division': '41',
#   'Avg_award_value': 5673772.17,
#   'Max_award_value': 7369596.5,
#   'Count_award_value': 3},
#  {'Year': 2012,
#   'Country': 'Greece',
#   'CPV_division': '92',
#   'Avg_award_value': 155475.0,
#   'Max_award_value': 200000,
#   'Count_award_value': 2},
#  {'Year': 2013,
#   'Country': 'Belgium',
#   'CPV_division': '43',
#   'Avg_award_value': 77000.74,
#   'Max_award_value': 197746.47,
#   'Count_award_value': 10},
#  {'Year': 2009,
#   'Country': 'Bulgaria',
#   'CPV_division': '22',
#   'Avg_award_value': 115552.94,
#   'Max_award_value': 312489.62,
#   'Count_award_value': 26},
#  {'Year': 2013,
#   'Country': 'Lithuania',
#   'CPV_division': '41',
#   'Avg_award_value': 17410.66,
#   'Max_award_value': 79039.55,
#   'Count_award_value': 169},
#  {'Year': 2010,
#   'Country': 'North Macedonia',
#   'CPV_division': '45',
#   'Avg_award_value': 82930650.42,
#   'Max_award_value': 314728542.37,
#   'Count_award_value': 4},
#  {'Year': 2013,
#   'Country': 'Latvia',
#   'CPV_division': '30',
#   'Avg_award_value': 897747.83,
#   'Max_award_value': 5736411.87,
#   'Count_award_value': 238},
#  {'Year': 2011,
#   'Country': 'Spain',
#   'CPV_division': '63',
#   'Avg_award_value': 3048045.83,
#   'Max_award_value': 63368300,
#   'Count_award_value': 75},
#  {'Year': 2016,
#   'Country': 'Lithuania',
#   'CPV_division': '34',
#   'Avg_award_value': 206600.94,
#   'Max_award_value': 3384000,
#   'Count_award_value': 343},
#  {'Year': 2017,
#   'Country': 'Bulgaria',
#   'CPV_division': '70',
#   'Avg_award_value': 204519.89,
#   'Max_award_value': 475508.74,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Greece',
#   'CPV_division': '38',
#   'Avg_award_value': 118044.04,
#   'Max_award_value': 1087096,
#   'Count_award_value': 67},
#  {'Year': 2018,
#   'Country': 'Greece',
#   'CPV_division': '70',
#   'Avg_award_value': 20502.22,
#   'Max_award_value': 46900,
#   'Count_award_value': 9},
#  {'Year': 2015,
#   'Country': 'Romania',
#   'CPV_division': '41',
#   'Avg_award_value': 857778.38,
#   'Max_award_value': 857778.38,
#   'Count_award_value': 1},
#  {'Year': 2017,
#   'Country': 'Finland',
#   'CPV_division': '35',
#   'Avg_award_value': 1613700.99,
#   'Max_award_value': 34000000,
#   'Count_award_value': 62},
#  {'Year': 2016,
#   'Country': 'Denmark',
#   'CPV_division': '42',
#   'Avg_award_value': 911372.41,
#   'Max_award_value': 6703581.05,
#   'Count_award_value': 18},
#  {'Year': 2010,
#   'Country': 'Finland',
#   'CPV_division': '19',
#   'Avg_award_value': 245865.71,
#   'Max_award_value': 599040,
#   'Count_award_value': 7},
#  {'Year': 2010,
#   'Country': 'Cyprus',
#   'CPV_division': '33',
#   'Avg_award_value': 315873.96,
#   'Max_award_value': 7862634,
#   'Count_award_value': 464},
#  {'Year': 2013,
#   'Country': 'Sweden',
#   'CPV_division': '22',
#   'Avg_award_value': 184939.03,
#   'Max_award_value': 184939.03,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Malta',
#   'CPV_division': '39',
#   'Avg_award_value': 383960.59,
#   'Max_award_value': 396321.19,
#   'Count_award_value': 2},
#  {'Year': 2011,
#   'Country': 'Spain',
#   'CPV_division': '70',
#   'Avg_award_value': 1559471.72,
#   'Max_award_value': 12308461.86,
#   'Count_award_value': 10},
#  {'Year': 2011,
#   'Country': 'Austria',
#   'CPV_division': '75',
#   'Avg_award_value': 862560.0,
#   'Max_award_value': 862560,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'France',
#   'CPV_division': '79',
#   'Avg_award_value': 4014190.44,
#   'Max_award_value': 9999999999,
#   'Count_award_value': 4791},
#  {'Year': 2016,
#   'Country': 'Belgium',
#   'CPV_division': '85',
#   'Avg_award_value': 897378.03,
#   'Max_award_value': 6751000,
#   'Count_award_value': 48},
#  {'Year': 2013,
#   'Country': 'Slovakia',
#   'CPV_division': '43',
#   'Avg_award_value': 576435.86,
#   'Max_award_value': 1230477,
#   'Count_award_value': 12},
#  {'Year': 2011,
#   'Country': 'Ireland',
#   'CPV_division': '98',
#   'Avg_award_value': 7297228.06,
#   'Max_award_value': 35000000,
#   'Count_award_value': 5},
#  {'Year': 2013,
#   'Country': 'Poland',
#   'CPV_division': '22',
#   'Avg_award_value': 359590.87,
#   'Max_award_value': 37623460.34,
#   'Count_award_value': 286},
#  {'Year': 2017,
#   'Country': 'Portugal',
#   'CPV_division': '24',
#   'Avg_award_value': 397588.27,
#   'Max_award_value': 1850000,
#   'Count_award_value': 12},
#  {'Year': 2017,
#   'Country': 'Spain',
#   'CPV_division': '77',
#   'Avg_award_value': 849052.62,
#   'Max_award_value': 18714017.44,
#   'Count_award_value': 276},
#  {'Year': 2016,
#   'Country': 'Belgium',
#   'CPV_division': '24',
#   'Avg_award_value': 197992.78,
#   'Max_award_value': 1810135.94,
#   'Count_award_value': 51},
#  {'Year': 2017,
#   'Country': 'Slovenia',
#   'CPV_division': '90',
#   'Avg_award_value': 300628.75,
#   'Max_award_value': 14400000,
#   'Count_award_value': 348},
#  {'Year': 2013,
#   'Country': 'Germany',
#   'CPV_division': '16',
#   'Avg_award_value': 259522.93,
#   'Max_award_value': 650000,
#   'Count_award_value': 29},
#  {'Year': 2018,
#   'Country': 'Slovakia',
#   'CPV_division': '65',
#   'Avg_award_value': 12999217.04,
#   'Max_award_value': 20735000,
#   'Count_award_value': 6},
#  {'Year': 2012,
#   'Country': 'Slovenia',
#   'CPV_division': '80',
#   'Avg_award_value': 26707.51,
#   'Max_award_value': 526683,
#   'Count_award_value': 74},
#  {'Year': 2011,
#   'Country': 'Switzerland',
#   'CPV_division': '15',
#   'Avg_award_value': 95963.01,
#   'Max_award_value': 443939.64,
#   'Count_award_value': 15},
#  {'Year': 2013,
#   'Country': 'Germany',
#   'CPV_division': '14',
#   'Avg_award_value': 542811.75,
#   'Max_award_value': 5051379.83,
#   'Count_award_value': 31},
#  {'Year': 2012,
#   'Country': 'Romania',
#   'CPV_division': '72',
#   'Avg_award_value': 1284731.03,
#   'Max_award_value': 24000000,
#   'Count_award_value': 134},
#  {'Year': 2018,
#   'Country': 'Hungary',
#   'CPV_division': '16',
#   'Avg_award_value': 285838.39,
#   'Max_award_value': 3200000,
#   'Count_award_value': 38},
#  {'Year': 2012,
#   'Country': 'Malta',
#   'CPV_division': '48',
#   'Avg_award_value': 147851.6,
#   'Max_award_value': 282129.19,
#   'Count_award_value': 2},
#  {'Year': 2009,
#   'Country': 'Portugal',
#   'CPV_division': '98',
#   'Avg_award_value': 1422636.59,
#   'Max_award_value': 2606000,
#   'Count_award_value': 16},
#  {'Year': 2011,
#   'Country': 'Hungary',
#   'CPV_division': '18',
#   'Avg_award_value': 102430.26,
#   'Max_award_value': 469688.8,
#   'Count_award_value': 36},
#  {'Year': 2011,
#   'Country': 'Romania',
#   'CPV_division': '15',
#   'Avg_award_value': 289199.73,
#   'Max_award_value': 15659715.51,
#   'Count_award_value': 477},
#  {'Year': 2009,
#   'Country': 'Czechia',
#   'CPV_division': '30',
#   'Avg_award_value': 1162634.33,
#   'Max_award_value': 12294306.79,
#   'Count_award_value': 105},
#  {'Year': 2009,
#   'Country': 'Slovakia',
#   'CPV_division': '24',
#   'Avg_award_value': 294621.67,
#   'Max_award_value': 581399,
#   'Count_award_value': 4},
#  {'Year': 2011,
#   'Country': 'Latvia',
#   'CPV_division': '71',
#   'Avg_award_value': 205330.05,
#   'Max_award_value': 2293642.93,
#   'Count_award_value': 127},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '22',
#   'Avg_award_value': 269573.69,
#   'Max_award_value': 4500000,
#   'Count_award_value': 96},
#  {'Year': 2009,
#   'Country': 'Germany',
#   'CPV_division': '51',
#   'Avg_award_value': 711268.83,
#   'Max_award_value': 4118548.74,
#   'Count_award_value': 29},
#  {'Year': 2016,
#   'Country': 'Switzerland',
#   'CPV_division': '66',
#   'Avg_award_value': 1222399.16,
#   'Max_award_value': 40527740.43,
#   'Count_award_value': 59},
#  {'Year': 2018,
#   'Country': 'Switzerland',
#   'CPV_division': '34',
#   'Avg_award_value': 1763332.08,
#   'Max_award_value': 33618898.42,
#   'Count_award_value': 86},
#  {'Year': 2016,
#   'CPV_division': '92',
#   'Avg_award_value': 8169132.63,
#   'Max_award_value': 130000000,
#   'Count_award_value': 53},
#  {'Year': 2010,
#   'Country': 'Sweden',
#   'CPV_division': '63',
#   'Avg_award_value': 239490.41,
#   'Max_award_value': 707537.77,
#   'Count_award_value': 9},
#  {'Year': 2018,
#   'Country': 'Ireland',
#   'CPV_division': '60',
#   'Avg_award_value': 1398963.77,
#   'Max_award_value': 10000000,
#   'Count_award_value': 227},
#  {'Year': 2018,
#   'Country': 'Luxembourg',
#   'CPV_division': '75',
#   'Avg_award_value': 911600.0,
#   'Max_award_value': 1700000,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'CPV_division': '65',
#   'Avg_award_value': 370319.81,
#   'Max_award_value': 472900.36,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Sweden',
#   'CPV_division': '31',
#   'Avg_award_value': 429858.93,
#   'Max_award_value': 10400199.64,
#   'Count_award_value': 143},
#  {'Year': 2011,
#   'Country': 'Slovakia',
#   'CPV_division': '38',
#   'Avg_award_value': 802186.81,
#   'Max_award_value': 9000000,
#   'Count_award_value': 84},
#  {'Year': 2009,
#   'Country': 'Belgium',
#   'CPV_division': '48',
#   'Avg_award_value': 857428.62,
#   'Max_award_value': 10249873,
#   'Count_award_value': 49},
#  {'Year': 2009,
#   'Country': 'Italy',
#   'CPV_division': '15',
#   'Avg_award_value': 437694.69,
#   'Max_award_value': 8161603.5,
#   'Count_award_value': 191},
#  {'Year': 2017,
#   'Country': 'Greece',
#   'CPV_division': '37',
#   'Avg_award_value': 231620.14,
#   'Max_award_value': 244037,
#   'Count_award_value': 3},
#  {'Year': 2018,
#   'Country': 'Italy',
#   'CPV_division': '22',
#   'Avg_award_value': 780960.62,
#   'Max_award_value': 16207536.5,
#   'Count_award_value': 70},
#  {'Year': 2009,
#   'Country': 'Romania',
#   'CPV_division': '76',
#   'Avg_award_value': 1035567.47,
#   'Max_award_value': 1245643.77,
#   'Count_award_value': 2},
#  {'Year': 2014,
#   'Country': 'Hungary',
#   'CPV_division': '48',
#   'Avg_award_value': 3973198.51,
#   'Max_award_value': 29153572.93,
#   'Count_award_value': 51},
#  {'Year': 2017,
#   'Country': 'Hungary',
#   'CPV_division': '66',
#   'Avg_award_value': 2984288.31,
#   'Max_award_value': 107490543.92,
#   'Count_award_value': 51},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '43',
#   'Avg_award_value': 401416.5,
#   'Max_award_value': 17309050.93,
#   'Count_award_value': 534},
#  {'Year': 2011,
#   'Country': 'Spain',
#   'CPV_division': '18',
#   'Avg_award_value': 251929.76,
#   'Max_award_value': 6701018,
#   'Count_award_value': 194},
#  {'Year': 2017,
#   'Country': 'Latvia',
#   'CPV_division': '72',
#   'Avg_award_value': 985227.11,
#   'Max_award_value': 25625490.67,
#   'Count_award_value': 85},
#  {'Year': 2013,
#   'Country': 'Finland',
#   'CPV_division': '15',
#   'Avg_award_value': 1376990.82,
#   'Max_award_value': 4000000,
#   'Count_award_value': 41},
#  {'Year': 2010,
#   'Country': 'Latvia',
#   'CPV_division': '48',
#   'Avg_award_value': 700938.56,
#   'Max_award_value': 5640715.39,
#   'Count_award_value': 103},
#  {'Year': 2009,
#   'Country': 'Denmark',
#   'CPV_division': '34',
#   'Avg_award_value': 371956.26,
#   'Max_award_value': 5340979.29,
#   'Count_award_value': 66},
#  {'Year': 2017,
#   'Country': 'Lithuania',
#   'CPV_division': '37',
#   'Avg_award_value': 217479.67,
#   'Max_award_value': 283918.07,
#   'Count_award_value': 2},
#  {'Year': 2015,
#   'Country': 'Switzerland',
#   'CPV_division': '37',
#   'Avg_award_value': 250764.96,
#   'Max_award_value': 250764.96,
#   'Count_award_value': 1},
#  {'Year': 2012,
#   'Country': 'Finland',
#   'CPV_division': '42',
#   'Avg_award_value': 660511.62,
#   'Max_award_value': 3096000,
#   'Count_award_value': 21},
#  {'Year': 2012,
#   'Country': 'Portugal',
#   'CPV_division': '19',
#   'Avg_award_value': 26039.96,
#   'Max_award_value': 367070,
#   'Count_award_value': 22},
#  {'Year': 2015,
#   'Country': 'Netherlands',
#   'CPV_division': '30',
#   'Avg_award_value': 474169.17,
#   'Max_award_value': 3280000,
#   'Count_award_value': 54},
#  {'Year': 2010,
#   'Country': 'Romania',
#   'CPV_division': '45',
#   'Avg_award_value': 8322718.56,
#   'Max_award_value': 142443378.76,
#   'Count_award_value': 339},
#  {'Year': 2015,
#   'Country': 'Slovakia',
#   'CPV_division': '38',
#   'Avg_award_value': 1469150.06,
#   'Max_award_value': 15727000,
#   'Count_award_value': 133},
#  {'Year': 2011,
#   'Country': 'Netherlands',
#   'CPV_division': '90',
#   'Avg_award_value': 506911.02,
#   'Max_award_value': 6800000,
#   'Count_award_value': 175},
#  {'Year': 2015,
#   'Country': 'Romania',
#   'CPV_division': '90',
#   'Avg_award_value': 913099.62,
#   'Max_award_value': 37719273.44,
#   'Count_award_value': 260},
#  {'Year': 2018,
#   'Country': 'Slovakia',
#   'CPV_division': '64',
#   'Avg_award_value': 2037884.54,
#   'Max_award_value': 6804000,
#   'Count_award_value': 8},
#  {'Year': 2017,
#   'Country': 'Romania',
#   'CPV_division': '33',
#   'Avg_award_value': 64740.86,
#   'Max_award_value': 32002939.6,
#   'Count_award_value': 36368},
#  {'Year': 2016,
#   'Country': 'Portugal',
#   'CPV_division': '50',
#   'Avg_award_value': 211298.75,
#   'Max_award_value': 1500000,
#   'Count_award_value': 142},
#  {'Year': 2015,
#   'Country': 'Germany',
#   'CPV_division': '15',
#   'Avg_award_value': 341876.98,
#   'Max_award_value': 3890000,
#   'Count_award_value': 66},
#  {'Year': 2010,
#   'CPV_division': '45',
#   'Avg_award_value': 20929581.7,
#   'Max_award_value': 704391633.81,
#   'Count_award_value': 499},
#  {'Year': 2016,
#   'Country': 'Portugal',
#   'CPV_division': '45',
#   'Avg_award_value': 6039911.01,
#   'Max_award_value': 30542288.25,
#   'Count_award_value': 46},
#  {'Year': 2015,
#   'Country': 'Italy',
#   'CPV_division': '85',
#   'Avg_award_value': 2536460.25,
#   'Max_award_value': 585768024,
#   'Count_award_value': 571},
#  {'Year': 2015,
#   'Country': 'North Macedonia',
#   'CPV_division': '66',
#   'Avg_award_value': 431557.43,
#   'Max_award_value': 2215104.12,
#   'Count_award_value': 10},
#  {'Year': 2009,
#   'Country': 'Finland',
#   'CPV_division': '60',
#   'Avg_award_value': 967326.91,
#   'Max_award_value': 111500000,
#   'Count_award_value': 169},
#  {'Year': 2017,
#   'Country': 'Spain',
#   'CPV_division': '14',
#   'Avg_award_value': 423948.55,
#   'Max_award_value': 7175729,
#   'Count_award_value': 64},
#  {'Year': 2016,
#   'Country': 'Slovenia',
#   'CPV_division': '60',
#   'Avg_award_value': 210028.68,
#   'Max_award_value': 3770000,
#   'Count_award_value': 248},
#  {'Year': 2013,
#   'Country': 'Poland',
#   'CPV_division': '92',
#   'Avg_award_value': 618921.45,
#   'Max_award_value': 2915339,
#   'Count_award_value': 275},
#  {'Year': 2015,
#   'Country': 'Greece',
#   'CPV_division': '85',
#   'Avg_award_value': 118675.74,
#   'Max_award_value': 4753739.84,
#   'Count_award_value': 907},
#  {'Year': 2015,
#   'Country': 'Estonia',
#   'CPV_division': '50',
#   'Avg_award_value': 212955.55,
#   'Max_award_value': 800134.21,
#   'Count_award_value': 26},
#  {'Year': 2016,
#   'Country': 'Slovenia',
#   'CPV_division': '64',
#   'Avg_award_value': 124859.2,
#   'Max_award_value': 6197946.69,
#   'Count_award_value': 123},
#  {'Year': 2018,
#   'Country': 'Luxembourg',
#   'CPV_division': '80',
#   'Avg_award_value': 1711190.0,
#   'Max_award_value': 3139500,
#   'Count_award_value': 18},
#  {'Year': 2016,
#   'Country': 'Poland',
#   'CPV_division': '71',
#   'Avg_award_value': 393798.51,
#   'Max_award_value': 32986077.03,
#   'Count_award_value': 1307},
#  {'Year': 2009,
#   'Country': 'Belgium',
#   'CPV_division': '70',
#   'Avg_award_value': 5428367.0,
#   'Max_award_value': 5428367,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Poland',
#   'CPV_division': '15',
#   'Avg_award_value': 100984.27,
#   'Max_award_value': 4929710.09,
#   'Count_award_value': 1145},
#  {'Year': 2014,
#   'Country': 'Germany',
# ...
#   'Max_award_value': 174452.93,
#   'Count_award_value': 8},
#  {'Year': 2013,
#   'Country': 'Romania',
#   'CPV_division': '32',
#   'Avg_award_value': 862827.25,
#   'Max_award_value': 27119360.94,
#   'Count_award_value': 60},
#  {'Year': 2018,
#   'Country': 'Latvia',
#   'CPV_division': '44',
#   'Avg_award_value': 207356.84,
#   'Max_award_value': 882724,
#   'Count_award_value': 39},
#  {'Year': 2016,
#   'Country': 'Croatia',
#   'CPV_division': '33',
#   'Avg_award_value': 94196.9,
#   'Max_award_value': 13800307.34,
#   'Count_award_value': 3811},
#  {'Year': 2012,
#   'Country': 'Luxembourg',
#   'CPV_division': '90',
#   'Avg_award_value': 219661.7,
#   'Max_award_value': 610591,
#   'Count_award_value': 11},
#  {'Year': 2018,
#   'Country': 'Italy',
#   'CPV_division': '45',
#   'Avg_award_value': 10766097.56,
#   'Max_award_value': 376669803.26,
#   'Count_award_value': 498},
#  {'Year': 2015,
#   'Country': 'Czechia',
#   'CPV_division': '72',
#   'Avg_award_value': 528160.22,
#   'Max_award_value': 10484255.29,
#   'Count_award_value': 402},
#  {'Year': 2018,
#   'Country': 'Portugal',
#   'CPV_division': '19',
#   'Avg_award_value': 38366.73,
#   'Max_award_value': 569700,
#   'Count_award_value': 36},
#  {'Year': 2010,
#   'Country': 'Austria',
#   'CPV_division': '14',
#   'Avg_award_value': 361759.39,
#   'Max_award_value': 3008400,
#   'Count_award_value': 21},
#  {'Year': 2009,
#   'Country': 'Portugal',
#   'CPV_division': '15',
#   'Avg_award_value': 756269.17,
#   'Max_award_value': 4631349.5,
#   'Count_award_value': 33},
#  {'Year': 2018,
#   'Country': 'North Macedonia',
#   'CPV_division': '71',
#   'Avg_award_value': 76708.11,
#   'Max_award_value': 704233.42,
#   'Count_award_value': 60},
#  {'Year': 2016,
#   'Country': 'Belgium',
#   'CPV_division': '50',
#   'Avg_award_value': 918397.51,
#   'Max_award_value': 15000000,
#   'Count_award_value': 137},
#  {'Year': 2014,
#   'Country': 'Germany',
#   'CPV_division': '33',
#   'Avg_award_value': 233544.19,
#   'Max_award_value': 3757000,
#   'Count_award_value': 314},
#  {'Year': 2011,
#   'Country': 'Greece',
#   'CPV_division': '22',
#   'Avg_award_value': 193649.41,
#   'Max_award_value': 950730,
#   'Count_award_value': 32},
#  {'Year': 2015,
#   'Country': 'Germany',
#   'CPV_division': '34',
#   'Avg_award_value': 528405.26,
#   'Max_award_value': 59913957.88,
#   'Count_award_value': 1186},
#  {'Year': 2011,
#   'Country': 'Germany',
#   'CPV_division': '92',
#   'Avg_award_value': 451149.27,
#   'Max_award_value': 733089.08,
#   'Count_award_value': 16},
#  {'Year': 2013,
#   'Country': 'Portugal',
#   'CPV_division': '43',
#   'Avg_award_value': 110614.85,
#   'Max_award_value': 164422.09,
#   'Count_award_value': 2},
#  {'Year': 2010,
#   'Country': 'Slovakia',
#   'CPV_division': '34',
#   'Avg_award_value': 5072646.96,
#   'Max_award_value': 74828032,
#   'Count_award_value': 67},
#  {'Year': 2018,
#   'Country': 'Greece',
#   'CPV_division': '45',
#   'Avg_award_value': 4769981.39,
#   'Max_award_value': 66580539.74,
#   'Count_award_value': 157},
#  {'Year': 2013,
#   'Country': 'Hungary',
#   'CPV_division': '22',
#   'Avg_award_value': 3385714.54,
#   'Max_award_value': 54875772,
#   'Count_award_value': 18},
#  {'Year': 2018,
#   'Country': 'Romania',
#   'CPV_division': '35',
#   'Avg_award_value': 533371.58,
#   'Max_award_value': 17527436.82,
#   'Count_award_value': 165},
#  {'Year': 2013,
#   'Country': 'Belgium',
#   'CPV_division': '64',
#   'Avg_award_value': 17605090.81,
#   'Max_award_value': 180592496,
#   'Count_award_value': 23},
#  {'Year': 2009,
#   'Country': 'Bulgaria',
#   'CPV_division': '77',
#   'Avg_award_value': 231312.81,
#   'Max_award_value': 4899955.69,
#   'Count_award_value': 25},
#  {'Year': 2016,
#   'Country': 'Spain',
#   'CPV_division': '73',
#   'Avg_award_value': 638599.35,
#   'Max_award_value': 6000000,
#   'Count_award_value': 56},
#  {'Year': 2014,
#   'Country': 'Portugal',
#   'CPV_division': '75',
#   'Avg_award_value': 49054.73,
#   'Max_award_value': 64210.07,
#   'Count_award_value': 3},
#  {'Year': 2014,
#   'Country': 'Switzerland',
#   'CPV_division': '98',
#   'Avg_award_value': 3306593.33,
#   'Max_award_value': 16128725.51,
#   'Count_award_value': 24},
#  {'Year': 2017,
#   'Country': 'Netherlands',
#   'CPV_division': '64',
#   'Avg_award_value': 1376300.74,
#   'Max_award_value': 20000000,
#   'Count_award_value': 75},
#  {'Year': 2014,
#   'Country': 'Switzerland',
#   'CPV_division': '31',
#   'Avg_award_value': 1552963.05,
#   'Max_award_value': 9022106.04,
#   'Count_award_value': 43},
#  {'Year': 2011,
#   'Country': 'Germany',
#   'CPV_division': '43',
#   'Avg_award_value': 436144.43,
#   'Max_award_value': 10872782,
#   'Count_award_value': 43},
#  {'Year': 2010,
#   'Country': 'Austria',
#   'CPV_division': '39',
#   'Avg_award_value': 397885.99,
#   'Max_award_value': 7720967.5,
#   'Count_award_value': 75},
#  {'Year': 2017,
#   'Country': 'Czechia',
#   'CPV_division': '72',
#   'Avg_award_value': 694525.34,
#   'Max_award_value': 66725273.34,
#   'Count_award_value': 678},
#  {'Year': 2012,
#   'Country': 'Ireland',
#   'CPV_division': '31',
#   'Avg_award_value': 162864.0,
#   'Max_award_value': 162864,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Poland',
#   'CPV_division': '43',
#   'Avg_award_value': 779067.07,
#   'Max_award_value': 21956094.76,
#   'Count_award_value': 305},
#  {'Year': 2018,
#   'Country': 'Portugal',
#   'CPV_division': '79',
#   'Avg_award_value': 972896.74,
#   'Max_award_value': 205849956,
#   'Count_award_value': 287},
#  {'Year': 2009,
#   'Country': 'Slovenia',
#   'CPV_division': '71',
#   'Avg_award_value': 393896.54,
#   'Max_award_value': 10433984.17,
#   'Count_award_value': 81},
#  {'Year': 2018,
#   'Country': 'Slovenia',
#   'CPV_division': '60',
#   'Avg_award_value': 68701.55,
#   'Max_award_value': 4474910,
#   'Count_award_value': 568},
#  {'Year': 2015,
#   'Country': 'Latvia',
#   'CPV_division': '48',
#   'Avg_award_value': 6440807.19,
#   'Max_award_value': 20000000,
#   'Count_award_value': 280},
#  {'Year': 2012,
#   'Country': 'Ireland',
#   'CPV_division': '30',
#   'Avg_award_value': 412303.52,
#   'Max_award_value': 1056910.57,
#   'Count_award_value': 3},
#  {'Year': 2013,
#   'Country': 'Croatia',
#   'CPV_division': '45',
#   'Avg_award_value': 36337.76,
#   'Max_award_value': 36337.76,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'Germany',
#   'CPV_division': '24',
#   'Avg_award_value': 407325.89,
#   'Max_award_value': 2564025.04,
#   'Count_award_value': 49},
#  {'Year': 2017,
#   'Country': 'Slovenia',
#   'CPV_division': '19',
#   'Avg_award_value': 168219.36,
#   'Max_award_value': 547890.4,
#   'Count_award_value': 8},
#  {'Year': 2012,
#   'Country': 'Estonia',
#   'CPV_division': '31',
#   'Avg_award_value': 374547.74,
#   'Max_award_value': 2267580,
#   'Count_award_value': 23},
#  {'Year': 2014,
#   'Country': 'Portugal',
#   'CPV_division': '50',
#   'Avg_award_value': 2407772.05,
#   'Max_award_value': 55189472,
#   'Count_award_value': 60},
#  {'Year': 2018,
#   'Country': 'Portugal',
#   'CPV_division': '76',
#   'Avg_award_value': 302743.0,
#   'Max_award_value': 302743,
#   'Count_award_value': 1},
#  {'Year': 2009,
#   'Country': 'Latvia',
#   'CPV_division': '22',
#   'Avg_award_value': 283191.02,
#   'Max_award_value': 283191.02,
#   'Count_award_value': 1},
#  {'Year': 2015,
#   'Country': 'Estonia',
#   'CPV_division': '30',
#   'Avg_award_value': 86520.03,
#   'Max_award_value': 578497.2,
#   'Count_award_value': 32},
#  {'Year': 2015,
#   'Country': 'North Macedonia',
#   'CPV_division': '30',
#   'Avg_award_value': 17885.05,
#   'Max_award_value': 124977.68,
#   'Count_award_value': 35},
#  {'Year': 2009,
#   'Country': 'Germany',
#   'CPV_division': '22',
#   'Avg_award_value': 152780.74,
#   'Max_award_value': 2000000,
#   'Count_award_value': 243},
#  {'Year': 2009,
#   'Country': 'Austria',
#   'CPV_division': '76',
#   'Avg_award_value': 3000000.0,
#   'Max_award_value': 3000000,
#   'Count_award_value': 1},
#  {'Year': 2018,
#   'Country': 'Spain',
#   'CPV_division': '75',
#   'Avg_award_value': 814843.14,
#   'Max_award_value': 22811365.56,
#   'Count_award_value': 115},
#  {'Year': 2009,
#   'Country': 'Netherlands',
#   'CPV_division': '39',
#   'Avg_award_value': 613230.59,
#   'Max_award_value': 2961683.03,
#   'Count_award_value': 12},
#  {'Year': 2012,
#   'Country': 'Spain',
#   'CPV_division': '65',
#   'Avg_award_value': 2411492.47,
#   'Max_award_value': 48227180,
#   'Count_award_value': 56},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '72',
#   'Avg_award_value': 1068356.89,
#   'Max_award_value': 31305404,
#   'Count_award_value': 831},
#  {'Year': 2015,
#   'Country': 'Lithuania',
#   'CPV_division': '41',
#   'Avg_award_value': 746450.88,
#   'Max_award_value': 746450.88,
#   'Count_award_value': 1},
#  {'Year': 2014,
#   'Country': 'Slovakia',
#   'CPV_division': '72',
#   'Avg_award_value': 9089442.64,
#   'Max_award_value': 1014550020,
#   'Count_award_value': 152},
#  {'Year': 2018,
#   'Country': 'Bulgaria',
#   'CPV_division': '14',
#   'Avg_award_value': 241429.33,
#   'Max_award_value': 1533899.13,
#   'Count_award_value': 12},
#  {'Year': 2016,
#   'Country': 'Austria',
#   'CPV_division': '92',
#   'Avg_award_value': 162056.05,
#   'Max_award_value': 192075,
#   'Count_award_value': 2},
#  {'Year': 2016,
#   'Country': 'France',
#   'CPV_division': '37',
#   'Avg_award_value': 131516.67,
#   'Max_award_value': 2332000,
#   'Count_award_value': 293},
#  {'Year': 2009,
#   'Country': 'Slovakia',
#   'CPV_division': '35',
#   'Avg_award_value': 1999606.8,
#   'Max_award_value': 6225811.5,
#   'Count_award_value': 15},
#  {'Year': 2012,
#   'Country': 'Switzerland',
#   'CPV_division': '79',
#   'Avg_award_value': 686937.9,
#   'Max_award_value': 2489006.89,
#   'Count_award_value': 27},
#  {'Year': 2013,
#   'Country': 'Netherlands',
#   'CPV_division': '79',
#   'Avg_award_value': 678006.24,
#   'Max_award_value': 28580002,
#   'Count_award_value': 215},
#  {'Year': 2011,
#   'Country': 'Norway',
#   'CPV_division': '33',
#   'Avg_award_value': 1150179.38,
#   'Max_award_value': 3592783.64,
#   'Count_award_value': 20},
#  {'Year': 2014,
#   'Country': 'Spain',
#   'CPV_division': '79',
#   'Avg_award_value': 2016288.88,
#   'Max_award_value': 197478000,
#   'Count_award_value': 496},
#  {'Year': 2010,
#   'Country': 'Switzerland',
#   'CPV_division': '22',
#   'Avg_award_value': 1068844.39,
#   'Max_award_value': 3246365.65,
#   'Count_award_value': 6},
#  {'Year': 2013,
#   'Country': 'Austria',
#   'CPV_division': '79',
#   'Avg_award_value': 511513.33,
#   'Max_award_value': 6540320,
#   'Count_award_value': 57},
#  {'Year': 2010,
#   'Country': 'Hungary',
#   'CPV_division': '18',
#   'Avg_award_value': 92437.98,
#   'Max_award_value': 1597370.81,
#   'Count_award_value': 62},
#  {'Year': 2009,
#   'Country': 'Portugal',
#   'CPV_division': '90',
#   'Avg_award_value': 302067.35,
#   'Max_award_value': 2942825.42,
#   'Count_award_value': 74},
#  {'Year': 2009,
#   'Country': 'Norway',
#   'CPV_division': '35',
#   'Avg_award_value': 2600000.0,
#   'Max_award_value': 2600000,
#   'Count_award_value': 1},
#  {'Year': 2013,
#   'Country': 'Switzerland',
#   'CPV_division': '33',
#   'Avg_award_value': 506550.25,
#   'Max_award_value': 2355616.93,
#   'Count_award_value': 19},
#  {'Year': 2014,
#   'Country': 'Finland',
#   'CPV_division': '73',
#   'Avg_award_value': 652589.53,
#   'Max_award_value': 10039015,
#   'Count_award_value': 26},
#  {'Year': 2017,
#   'Country': 'Switzerland',
#   'CPV_division': '15',
#   'Avg_award_value': 6949717.36,
#   'Max_award_value': 51116043.85,
#   'Count_award_value': 11},
#  {'Year': 2015,
#   'Country': 'Sweden',
#   'CPV_division': '71',
#   'Avg_award_value': 975020.99,
#   'Max_award_value': 19244133.21,
#   'Count_award_value': 60},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '92',
#   'Avg_award_value': 1647927.04,
#   'Max_award_value': 64849048,
#   'Count_award_value': 82},
#  {'Year': 2010,
#   'Country': 'Romania',
#   'CPV_division': '63',
#   'Avg_award_value': 544724.6,
#   'Max_award_value': 1916509.19,
#   'Count_award_value': 21},
#  {'Year': 2017,
#   'Country': 'Austria',
#   'CPV_division': '15',
#   'Avg_award_value': 340965.39,
#   'Max_award_value': 8958749,
#   'Count_award_value': 186},
#  {'Year': 2017,
#   'Country': 'Norway',
#   'CPV_division': '48',
#   'Avg_award_value': 1400175.24,
#   'Max_award_value': 21527134.95,
#   'Count_award_value': 108},
#  {'Year': 2014,
#   'Country': 'Cyprus',
#   'CPV_division': '90',
#   'Avg_award_value': 755837.8,
#   'Max_award_value': 1982875,
#   'Count_award_value': 5},
#  {'Year': 2011,
#   'Country': 'Hungary',
#   'CPV_division': '65',
#   'Avg_award_value': 753780.98,
#   'Max_award_value': 1299951.98,
#   'Count_award_value': 2},
#  {'Year': 2013,
#   'Country': 'Netherlands',
#   'CPV_division': '45',
#   'Avg_award_value': 6639888.53,
#   'Max_award_value': 156000000,
#   'Count_award_value': 234},
#  {'Year': 2013,
#   'Country': 'Bulgaria',
#   'CPV_division': '71',
#   'Avg_award_value': 519675.97,
#   'Max_award_value': 31791676,
#   'Count_award_value': 426},
#  {'Year': 2012,
#   'Country': 'Germany',
#   'CPV_division': '60',
#   'Avg_award_value': 370097.15,
#   'Max_award_value': 17883528,
#   'Count_award_value': 558},
#  {'Year': 2014,
#   'Country': 'Czechia',
#   'CPV_division': '14',
#   'Avg_award_value': 309712.15,
#   'Max_award_value': 12950000,
#   'Count_award_value': 143},
#  {'Year': 2016,
#   'Country': 'Netherlands',
#   'CPV_division': '44',
#   'Avg_award_value': 6505595.62,
#   'Max_award_value': 43000000,
#   'Count_award_value': 31},
#  {'Year': 2018,
#   'Country': 'Luxembourg',
#   'CPV_division': '38',
#   'Avg_award_value': 390894.49,
#   'Max_award_value': 794380,
#   'Count_award_value': 13},
#  {'Year': 2012,
#   'Country': 'Hungary',
#   'CPV_division': '80',
#   'Avg_award_value': 250782.99,
#   'Max_award_value': 548469.79,
#   'Count_award_value': 5},
#  {'Year': 2010,
#   'Country': 'Belgium',
#   'CPV_division': '22',
#   'Avg_award_value': 191806.99,
#   'Max_award_value': 973540.2,
#   'Count_award_value': 29},
#  {'Year': 2014,
#   'Country': 'Latvia',
#   'CPV_division': '92',
#   'Avg_award_value': 232882.98,
#   'Max_award_value': 371900.8,
#   'Count_award_value': 7},
#  {'Year': 2010,
#   'Country': 'Bulgaria',
#   'CPV_division': '22',
#   'Avg_award_value': 139507.19,
#   'Max_award_value': 1074286.74,
#   'Count_award_value': 26},
#  {'Year': 2010,
#   'Country': 'Slovakia',
#   'CPV_division': '50',
#   'Avg_award_value': 2292529.12,
#   'Max_award_value': 46800000,
#   'Count_award_value': 44},
#  {'Year': 2011,
#   'Country': 'Belgium',
#   'CPV_division': '41',
#   'Avg_award_value': 7998519.75,
#   'Max_award_value': 9686145,
#   'Count_award_value': 2},
#  {'Year': 2016,
#   'Country': 'Netherlands',
#   'CPV_division': '45',
#   'Avg_award_value': 9449607.16,
#   'Max_award_value': 320911000,
#   'Count_award_value': 258},
#  {'Year': 2018,
#   'Country': 'Denmark',
#   'CPV_division': '79',
#   'Avg_award_value': 12884225.9,
#   'Max_award_value': 718641000,
#   'Count_award_value': 171},
#  {'Year': 2012,
#   'CPV_division': '15',
#   'Avg_award_value': 3953966.0,
#   'Max_award_value': 61319708.46,
#   'Count_award_value': 71},
#  {'Year': 2010,
#   'Country': 'Italy',
#   'CPV_division': '43',
#   'Avg_award_value': 316272.88,
#   'Max_award_value': 587286,
#   'Count_award_value': 14},
#  {'Year': 2011,
#   'Country': 'Bulgaria',
#   'CPV_division': '43',
#   'Avg_award_value': 867600.2,
#   'Max_award_value': 1592150.53,
#   'Count_award_value': 6},
#  {'Year': 2013,
#   'Country': 'Finland',
#   'CPV_division': '22',
#   'Avg_award_value': 877749.29,
#   'Max_award_value': 4675000,
#   'Count_award_value': 7},
#  {'Year': 2015,
#   'Country': 'Austria',
#   'CPV_division': '24',
#   'Avg_award_value': 548598.58,
#   'Max_award_value': 1362240,
#   'Count_award_value': 12},
#  {'Year': 2009,
#   'Country': 'Czechia',
#   'CPV_division': '76',
#   'Avg_award_value': 98203.14,
#   'Max_award_value': 98203.14,
#   'Count_award_value': 1},
#  {'Year': 2017,
#   'Country': 'Greece',
#   'CPV_division': '24',
#   'Avg_award_value': 512213.51,
#   'Max_award_value': 7499000,
#   'Count_award_value': 35},
#  {'Year': 2009,
#   'Country': 'Hungary',
#   'CPV_division': '70',
#   'Avg_award_value': 568348.66,
#   'Max_award_value': 1248570.41,
#   'Count_award_value': 5},
#  {'Year': 2011,
#   'Country': 'France',
#   'CPV_division': '19',
#   'Avg_award_value': 921963.27,
#   'Max_award_value': 161370000,
#   'Count_award_value': 205},
#  {'Year': 2011,
#   'Country': 'Portugal',
#   'CPV_division': '60',
#   'Avg_award_value': 319545.45,
#   'Max_award_value': 10760000,
#   'Count_award_value': 121},
#  {'Year': 2012,
#   'Country': 'Finland',
#   'CPV_division': '35',
#   'Avg_award_value': 433617.8,
#   'Max_award_value': 2799656,
#   'Count_award_value': 42},
#  ...]

# %%
result11 = result11_1+result11_2

# %%
a11 = col_results.insert_one(
    {'question' : 11,
     'answer' : result11
    })

# %% [markdown]
# ##### Open Question

# %% [markdown]
# **12.** Knowing that the dataset has wrongly inserted values, more in particular impossible 'VALUE_EURO' and similar values, how would you deal with this situation?

# %%
result12 = '''Firstly, to have a clear view about the numerical variables, we would further understand the data using distribution and box plot visualizations. We would also check if the absolute difference between the VALUE_EURO and the AWARD_VALUE_EURO is so big that raises a red flag or check if they are particular multiples (10x or 100x) of each other meaning that a value was wrongly inserted (comma in the wrong place).

As the contracting entity must keep a copy of the contracts, we could ask for the information that doesn't seem right. Additionaly, using the TED url, we could ask to the Publications Office for a copy of the contract notices and find the contracts of the contractor authority depending on the importance of the research that is being conducted. If this type of research couldn't be done, we would consider this values as outliers and we would treat them accordingly, removing them from the main analysis.

To look for other incoherencies, we would run coherence checks, such as looking for codes with the wrong number of digits. When inserted into the database, the codes should be inserted as strings instead of integers and the dates should have a standard known format.
'''

# %%
a12 = col_results.insert_one(
    {'question' : 12,
     'answer' : result12
    })
